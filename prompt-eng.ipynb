# %% [markdown]
# # Prompt Generation

# %% [markdown]
# This python notebook takes the pure_train.csv and extracts important linguistic features to create a proper prompt for the LLM

# %% [markdown]
# ## Libraries Imported

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from collections import defaultdict

# %% [markdown]
# ## Data Extraction and Cleaning

# %% [markdown]
# ### Extract from CSV File

# %%
df = pd.read_csv('./data/PURE_train.csv')

# %% [markdown]
# ### Drop Unused Columns

# %%
df = df.drop(columns=["Unnamed: 0"])

# %% [markdown]
# ### Renaming Columns

# %%
df = df.rename(columns={'Requirement':'text', 'Name of Doc': 'source', 'Req/Not Req': 'label'})

# %%
df['y'] = np.where(df['label'] == 'Req', 1, 0)

# %%
df.head()
# Out:
#                                                 text     source label  y
# 0  The solution should provide detailed context-s...  cctns.pdf   Req  1
# 1  The help should be accessible to the users bot...  cctns.pdf   Req  1
# 2  The solution should provide an interface for t...  cctns.pdf   Req  1
# 3  The solution should send alerts (e.g., email, ...  cctns.pdf   Req  1
# 4  The solution should enable the user to track t...  cctns.pdf   Req  1

# %% [markdown]
# ## Extracting Linguistic Features for Prompt Engineering

# %% [markdown]
# ### Count Vectorizer and Logistic Regression for Feature Importance

# %%
sources = df['source'].unique()
n_top = 20

# %%
ling_words = {}

for src in sources:
    # iterate each subset
    print("Source:", src)
    print("-"*20)
    subset = df[df["source"] == src]
    
    counts = subset["y"].value_counts()
    n_req = counts.get(1, 0)
    n_non = counts.get(0, 0)
    
    if n_req == 0 or n_non == 0:
        print("Skipping. Not enough data for a meaningful analysis.")
        continue
    
    # vectorizer
    vectorizer = CountVectorizer(
        ngram_range=(2, 5),
        min_df=2,
        lowercase=True
    )
    
    # use vectorizer for train and label set
    X = vectorizer.fit_transform(subset['text'])
    y = subset['y']
    
    # use logistic regression to obtain coeffecients
    lgrg = LogisticRegression()
    
    lgrg.fit(X, y)
    
    # coeffecients
    coef = lgrg.coef_[0]
    
    # feature names
    feature_names = vectorizer.get_feature_names_out()
    
    # get top 10 features for req
    req_values = []
    req_indices = np.argsort(coef)[-n_top:]
    for i in req_indices[::-1]:
        req_values.append((feature_names[i], coef[i]))
        print(f"Word: {feature_names[i]}, Weight: {coef[i]}")
    
    print()
    
    # get top 10 features for non-req
    nonreq_values = []
    notreq_indices = np.argsort(coef)[:n_top]
    for i in notreq_indices:
        nonreq_values.append((feature_names[i], coef[i]))
        print(f"Word: {feature_names[i]}, Weight: {coef[i]}")
    
    print()
    
    ling_words[src] = (req_values, nonreq_values)
# Out:
# Source: cctns.pdf
# --------------------
# Word: should be, Weight: 1.4157989627847516
# Word: the system, Weight: 0.9880781162690828
# Word: system should, Weight: 0.5586876624983365
# Word: the system should, Weight: 0.5586876624983365
# Word: the user, Weight: 0.5332939247621353
# Word: the system must, Weight: 0.4260760082279166
# Word: system must, Weight: 0.4260760082279166
# Word: iso 9241, Weight: 0.41643844850799244
# Word: in the, Weight: 0.37397087480479163
# Word: to be, Weight: 0.31396944643602964
# Word: to the, Weight: 0.27195057509459514
# Word: use of, Weight: 0.25372232275782
# Word: does not, Weight: 0.24451890650815353
# Word: must be, Weight: 0.2394118480426658
# Word: the same, Weight: 0.23352051299622414
# Word: solution should, Weight: 0.22184496607396428
# Word: to allow, Weight: 0.2059591329123451
# Word: the solution should, Weight: 0.20326315681050233
# Word: the solution, Weight: 0.20326315681050233
# Word: should be provided, Weight: 0.198557563954228
#
# Word: of the, Weight: -0.8658616679178002
# Word: the core, Weight: -0.6450682996755209
# Word: based on, Weight: -0.620453659984847
# Word: functional architecture, Weight: -0.5907271443447385
# Word: police and, Weight: -0.576643785523306
# Word: the cctns, Weight: -0.5530886937054229
# Word: with the courts, Weight: -0.5469147481332791
# Word: the courts, Weight: -0.5469147481332791
# Word: the functional, Weight: -0.5168157594552764
# Word: of the cctns, Weight: -0.5118253185515264
# Word: the guiding, Weight: -0.511117247097662
# Word: based on the, Weight: -0.49569367220140026
# Word: each of, Weight: -0.4861774805176833
# Word: each of the, Weight: -0.4861774805176833
# Word: the investigation, Weight: -0.480169201683027
# Word: with the, Weight: -0.47239659491645836
# Word: the investigation process, Weight: -0.4683426583974745
# Word: investigation process, Weight: -0.4683426583974745
# Word: architecture is, Weight: -0.4495058672116233
# Word: functional architecture is, Weight: -0.4495058672116233
#
# Source: dii.htm
# --------------------
# Word: shall be, Weight: 1.5947376704664893
# Word: the xs, Weight: 1.5645475428458588
# Word: mode this, Weight: 0.9865474317759844
# Word: services shall, Weight: 0.8853346186816241
# Word: xs shall, Weight: 0.8759338010818832
# Word: the xs shall, Weight: 0.8759338010818832
# Word: session time, Weight: 0.8084584632275852
# Word: data management, Weight: 0.753182137458903
# Word: and or, Weight: 0.702235909832838
# Word: other related, Weight: 0.6914477096846592
# Word: software shall be, Weight: 0.6723796344820147
# Word: precedence and, Weight: 0.6337162527601337
# Word: precedence and criticality, Weight: 0.6337162527601337
# Word: and criticality, Weight: 0.6337162527601337
# Word: level requirements, Weight: 0.63328596098457
# Word: the rts, Weight: 0.6279855211892155
# Word: in the rts, Weight: 0.6279855211892155
# Word: management services, Weight: 0.6216155823409639
# Word: data management services, Weight: 0.6216155823409639
# Word: in addition, Weight: 0.6198531057084753
#
# Word: information resources, Weight: -0.36782043881763654
# Word: information resource, Weight: -0.36437889561942066
# Word: for the, Weight: -0.29928108552440236
# Word: of xml, Weight: -0.29018419630187475
# Word: outlines the, Weight: -0.23885519373169017
# Word: database management, Weight: -0.1954419287372131
# Word: the information, Weight: -0.19306320118936812
# Word: and control, Weight: -0.19074941238681456
# Word: to an, Weight: -0.1751304587894452
# Word: and verification, Weight: -0.1747561918483649
# Word: xml tags, Weight: -0.1716039751516861
# Word: command and control, Weight: -0.17005666405482678
# Word: command and, Weight: -0.17005666405482678
# Word: data is, Weight: -0.16985378470741372
# Word: the coe, Weight: -0.168033817178999
# Word: capability to, Weight: -0.16543550712300556
# Word: these services, Weight: -0.1623454985803315
# Word: tags and, Weight: -0.1582443090666025
# Word: the software, Weight: -0.15726022777006451
# Word: an xml, Weight: -0.15497309825954186
#
# Source: gamma j.pdf
# --------------------
# Word: the system, Weight: 1.3621414240964314
# Word: system shall, Weight: 1.3190001311914579
# Word: the system shall, Weight: 1.178414079810777
# Word: will be, Weight: 1.0110252452214874
# Word: customer profiles, Weight: 0.7636863565160111
# Word: the specific, Weight: 0.6192238017630133
# Word: the system will, Weight: 0.5841263587982428
# Word: be able to, Weight: 0.5662311254977781
# Word: be able, Weight: 0.5662311254977781
# Word: shall be, Weight: 0.5550354355508331
# Word: internet connection, Weight: 0.5409535286195915
# Word: with the, Weight: 0.48972254440056406
# Word: will also, Weight: 0.48480950790156463
# Word: customer will, Weight: 0.47660281055973336
# Word: the customer will, Weight: 0.47660281055973336
# Word: credit card, Weight: 0.4641043318785845
# Word: of items, Weight: 0.45196798678102906
# Word: the inventory management, Weight: 0.4232485911100819
# Word: inventory management, Weight: 0.4232485911100819
# Word: through programmatic interface, Weight: 0.40692382311133596
#
# Word: of the, Weight: -0.8704387405477236
# Word: web store, Weight: -0.7090202713500172
# Word: the administrator, Weight: -0.4937576906425929
# Word: store inventory, Weight: -0.4029264252446687
# Word: yoggie corporation, Weight: -0.3928656018963748
# Word: system to, Weight: -0.3924708327121366
# Word: high priority, Weight: -0.3828003725705149
# Word: description of, Weight: -0.3501929765389615
# Word: the requirements, Weight: -0.3492796141910356
# Word: the web, Weight: -0.34850193889183834
# Word: sql based, Weight: -0.34526468158727214
# Word: sql based database, Weight: -0.34526468158727214
# Word: based database, Weight: -0.34526468158727214
# Word: use sql based database, Weight: -0.34526468158727214
# Word: use sql based, Weight: -0.34526468158727214
# Word: use sql, Weight: -0.34526468158727214
# Word: of system, Weight: -0.3238090259643086
# Word: be in, Weight: -0.3096462851788196
# Word: to ensure, Weight: -0.30890408127232
# Word: functional requirements, Weight: -0.30637196788726256
#
# Source: inventory.pdf
# --------------------
# Word: it is, Weight: 0.9792894387639592
# Word: administrative level, Weight: 0.9135032291564893
# Word: member can, Weight: 0.846582029173304
# Word: application should, Weight: 0.7620371902376639
# Word: backup operation, Weight: 0.6463816087922709
# Word: group member, Weight: 0.6196538483472238
# Word: the application, Weight: 0.595227919487366
# Word: request is, Weight: 0.5682980749326415
# Word: an inventory, Weight: 0.4975911670972654
# Word: any administrative level, Weight: 0.4787798176940993
# Word: approved by, Weight: 0.44816171505258623
# Word: should be, Weight: 0.44656774403249416
# Word: more than, Weight: 0.4319789434018874
# Word: when user, Weight: 0.41525778147461745
# Word: user according to, Weight: 0.40447424388566505
# Word: user according, Weight: 0.40447424388566505
# Word: be approved by, Weight: 0.39854042516243404
# Word: be approved, Weight: 0.39854042516243404
# Word: by user name, Weight: 0.3713309281076743
# Word: by user name and, Weight: 0.3713309281076743
#
# Word: inventory admin, Weight: -0.9706619051509673
# Word: use case, Weight: -0.7770473773335315
# Word: the following, Weight: -0.6419451906711997
# Word: request form, Weight: -0.48296961799313803
# Word: the inventory, Weight: -0.4633535173922632
# Word: is displayed, Weight: -0.42167793310440643
# Word: interface that, Weight: -0.4057501212028405
# Word: the use case, Weight: -0.4007800915442289
# Word: the use, Weight: -0.4007800915442289
# Word: message error, Weight: -0.3781536956673234
# Word: the system, Weight: -0.3778205039958439
# Word: on the, Weight: -0.37700224482665756
# Word: request to, Weight: -0.3628089917049737
# Word: user select, Weight: -0.3505698602443147
# Word: user enter, Weight: -0.3444825370829912
# Word: use case begins, Weight: -0.33521187274205017
# Word: case begins, Weight: -0.33521187274205017
# Word: inventory system, Weight: -0.3341687034539213
# Word: the iufa, Weight: -0.3093194073861154
# Word: any time, Weight: -0.3093194073861154
#
# Source: multi-mahjong.pdf
# --------------------
# Word: will be, Weight: 1.3715817106142723
# Word: the user, Weight: 1.1539474291587364
# Word: multimahjongserver will, Weight: 0.9797487911047145
# Word: the multimahjongserver will, Weight: 0.9797487911047145
# Word: unix box, Weight: 0.9291206197215848
# Word: the multimahjongserver, Weight: 0.8853516027145115
# Word: multi player, Weight: 0.7864514387090586
# Word: multimahjongclient will, Weight: 0.7615771271856723
# Word: the multimahjongclient will, Weight: 0.7566165726679255
# Word: program execution, Weight: 0.6989794117956805
# Word: option to, Weight: 0.6014129616967306
# Word: be able, Weight: 0.5670794114801041
# Word: be able to, Weight: 0.5670794114801041
# Word: multimahjongclient must, Weight: 0.5622266084286937
# Word: in the, Weight: 0.5548539296438212
# Word: another player, Weight: 0.5540030627002226
# Word: capable of, Weight: 0.5319087269133506
# Word: able to, Weight: 0.523578306177497
# Word: users who, Weight: 0.5179054568335938
# Word: the co, Weight: 0.5147331454478815
#
# Word: the client, Weight: -0.4207443139863226
# Word: the project, Weight: -0.4201611887804735
# Word: main window, Weight: -0.3867264752035359
# Word: and the, Weight: -0.34837009667940416
# Word: by the, Weight: -0.3433835669090743
# Word: the multimahjongclient program, Weight: -0.3326372506035459
# Word: multimahjongclient program, Weight: -0.3326372506035459
# Word: multimahjong is, Weight: -0.3294791582832765
# Word: to play, Weight: -0.3240466941609359
# Word: this document, Weight: -0.31865803874132226
# Word: for the, Weight: -0.31514823594965696
# Word: runs the, Weight: -0.29468742782435986
# Word: set of, Weight: -0.285837095576471
# Word: in this, Weight: -0.2759417752257522
# Word: the other, Weight: -0.26487665545414424
# Word: multimahjongserver is to, Weight: -0.2630678860767527
# Word: multimahjongserver is, Weight: -0.2630678860767527
# Word: the multimahjongserver is, Weight: -0.2630678860767527
# Word: the multimahjongserver is to, Weight: -0.2630678860767527
# Word: game and, Weight: -0.2557264282263557
#
# Source: beyond.pdf
# --------------------
# Word: the system, Weight: 0.7876591087383612
# Word: the ui, Weight: 0.6105436622405583
# Word: user interface, Weight: 0.5687615879730853
# Word: and the, Weight: 0.5262452938659955
# Word: should be, Weight: 0.5070779972026085
# Word: the firmware, Weight: 0.48461793129551256
# Word: the user, Weight: 0.44865078327912566
# Word: provide the, Weight: 0.43302631692565174
# Word: are not, Weight: 0.4281022103477934
# Word: because of, Weight: 0.4279025643908396
# Word: is an, Weight: 0.4228576594267923
# Word: the authoring tool, Weight: 0.42122695715002
# Word: the authoring, Weight: 0.42122695715002
# Word: authoring tool, Weight: 0.42122695715002
# Word: functionality we, Weight: 0.3999191905582257
# Word: this is, Weight: 0.39503853359818103
# Word: be implemented, Weight: 0.38776416222604937
# Word: must be, Weight: 0.3828704029882512
# Word: specifications are, Weight: 0.38248577461627464
# Word: the terminal, Weight: 0.3724588713205577
#
# Word: have been, Weight: -0.9298910230844633
# Word: there are, Weight: -0.6786635975978178
# Word: project are, Weight: -0.6408192428254206
# Word: and d8, Weight: -0.6290902003657596
# Word: the project, Weight: -0.6255521409878965
# Word: the contributions, Weight: -0.6225584416351109
# Word: these aspects, Weight: -0.6054529635029563
# Word: this document, Weight: -0.6039061138201094
# Word: architectural issues, Weight: -0.599013341167613
# Word: that the, Weight: -0.5914712669418233
# Word: common deliverable, Weight: -0.5776066110436584
# Word: the same, Weight: -0.5662183670073173
# Word: that are, Weight: -0.5220012800255734
# Word: the second, Weight: -0.5110545960905566
# Word: in this, Weight: -0.49606610046374094
# Word: in particular, Weight: -0.49192366520303277
# Word: functional specifications, Weight: -0.4718803184642796
# Word: it is, Weight: -0.4711081589626372
# Word: has been, Weight: -0.4619129380231218
# Word: this deliverable, Weight: -0.46045780545016374
#
# Source: elsfork.pdf
# --------------------
# Word: shall be, Weight: 1.7026783025884802
# Word: condition monitoring, Weight: 0.8174919250368706
# Word: the communication, Weight: 0.8133397338759047
# Word: scanning rate, Weight: 0.754657879406815
# Word: could be, Weight: 0.7490097276714194
# Word: at least, Weight: 0.7386724492396028
# Word: transport media, Weight: 0.7362954661568386
# Word: the physical, Weight: 0.7279618489455256
# Word: the communication system, Weight: 0.7080489287475323
# Word: functions and, Weight: 0.7005005906005891
# Word: may also, Weight: 0.69012999433237
# Word: data as, Weight: 0.6742233156931395
# Word: the following, Weight: 0.6559131674797126
# Word: and procedures, Weight: 0.6298901949773134
# Word: of programs, Weight: 0.6089763492277097
# Word: time critical, Weight: 0.606147904088994
# Word: time critical functions, Weight: 0.606147904088994
# Word: critical functions, Weight: 0.606147904088994
# Word: may be, Weight: 0.6011463505500304
# Word: standards and procedures, Weight: 0.5991023150587685
#
# Word: wind farm, Weight: -0.7773356931508631
# Word: the specification, Weight: -0.7561849317138732
# Word: used to, Weight: -0.6585659178060113
# Word: the different, Weight: -0.6527674135690588
# Word: iec 61850, Weight: -0.6523841774763633
# Word: the requirements, Weight: -0.5450930894059722
# Word: to the, Weight: -0.5366238474230328
# Word: communication network, Weight: -0.5214373783560571
# Word: iec 60870, Weight: -0.5165952796758563
# Word: the wind farm, Weight: -0.5155852415216623
# Word: or more, Weight: -0.5065751137577789
# Word: control of, Weight: -0.49816194729176105
# Word: functions are, Weight: -0.4914642970864054
# Word: there are, Weight: -0.4861676178313255
# Word: for an, Weight: -0.4796743334574763
# Word: by the, Weight: -0.46075124022781816
# Word: stands for, Weight: -0.46029134457211474
# Word: control system, Weight: -0.4600611715955715
# Word: data objects, Weight: -0.44969400757653505
# Word: there is, Weight: -0.444272198502155
#
# Source: esa.pdf
# --------------------
# Word: shall be, Weight: 1.2888987875804163
# Word: the apaf, Weight: 0.8341902822587284
# Word: swri shall, Weight: 0.614067858204486
# Word: swri shall provide, Weight: 0.5646880183599883
# Word: shall provide, Weight: 0.5646880183599883
# Word: system shall, Weight: 0.522157831875053
# Word: apaf system, Weight: 0.510731317235109
# Word: there are no, Weight: 0.44714026617538993
# Word: are no, Weight: 0.44714026617538993
# Word: the apaf system, Weight: 0.4310089325225689
# Word: there shall, Weight: 0.38737641075765844
# Word: there shall be, Weight: 0.38737641075765844
# Word: of the apaf, Weight: 0.32484124683803056
# Word: the apaf system shall, Weight: 0.32273228267127096
# Word: apaf system shall, Weight: 0.32273228267127096
# Word: aspera data, Weight: 0.32040486111453753
# Word: ap af, Weight: 0.3115114150206018
# Word: af system, Weight: 0.3115114150206018
# Word: ap af system, Weight: 0.3115114150206018
# Word: science analysis, Weight: 0.30940973489802176
#
# Word: each requirement, Weight: -0.5469747898294478
# Word: of the, Weight: -0.5062853116004444
# Word: will be, Weight: -0.4125212091286468
# Word: is to, Weight: -0.39525420574516507
# Word: requirement is, Weight: -0.3639293816410895
# Word: requirement may, Weight: -0.36299468775283505
# Word: number of, Weight: -0.3147977544720062
# Word: and archiving, Weight: -0.3135103879744279
# Word: from the, Weight: -0.2916500595740599
# Word: data system, Weight: -0.29040544413817454
# Word: each requirement shall, Weight: -0.280710038390544
# Word: each requirement shall be, Weight: -0.280710038390544
# Word: requirement shall, Weight: -0.280710038390544
# Word: requirement shall be, Weight: -0.280710038390544
# Word: in section, Weight: -0.2708153436731503
# Word: in form, Weight: -0.2515615556671679
# Word: that will, Weight: -0.23735766768590122
# Word: data products, Weight: -0.2367013856076412
# Word: data sets, Weight: -0.23005389404220786
# Word: the requirements, Weight: -0.22009274865276351
#
# Source: libra.doc
# --------------------
# Word: should be, Weight: 0.9335168106909659
# Word: should provide, Weight: 0.7758370900800022
# Word: the cluster, Weight: 0.7724546805276968
# Word: the maximum, Weight: 0.7123367441721028
# Word: be done, Weight: 0.706524550364165
# Word: will be, Weight: 0.6750168894165907
# Word: the job, Weight: 0.6362682647795718
# Word: this feature, Weight: 0.5732872580256306
# Word: cluster information, Weight: 0.528227428346593
# Word: will not, Weight: 0.4975552959439587
# Word: by sge, Weight: 0.4833641546660277
# Word: of sge, Weight: 0.46457792152898375
# Word: may be, Weight: 0.45804055746428146
# Word: able to, Weight: 0.4560045052295674
# Word: the scheduler, Weight: 0.4556605004959682
# Word: and scheduling, Weight: 0.4547909426616385
# Word: host and queue, Weight: 0.44518952753105956
# Word: host and, Weight: 0.44518952753105956
# Word: and queue, Weight: 0.44518952753105956
# Word: to the user, Weight: 0.4350484574051331
#
# Word: is the, Weight: -0.5633959095755406
# Word: will be used, Weight: -0.5304185235935857
# Word: the resource, Weight: -0.4786051935719139
# Word: high performance, Weight: -0.4733895275227199
# Word: by the user, Weight: -0.45006256117415006
# Word: freely available, Weight: -0.4298439341738784
# Word: cpu utilization, Weight: -0.423447325291451
# Word: to optimize, Weight: -0.423447325291451
# Word: to the, Weight: -0.41334023920629115
# Word: of the scheduler, Weight: -0.40851317509563057
# Word: the srs, Weight: -0.4066285487162396
# Word: as the, Weight: -0.40351996665304235
# Word: as they, Weight: -0.40163013367369854
# Word: they are, Weight: -0.37583441052771677
# Word: is an, Weight: -0.3678248611736261
# Word: users for, Weight: -0.36246827271366194
# Word: system the, Weight: -0.35248679696297114
# Word: the same, Weight: -0.35130534193238117
# Word: the process, Weight: -0.3495078136178238
# Word: provided in, Weight: -0.34132435008056666
#
# Source: npac.doc
# --------------------
# Word: sms shall, Weight: 2.781964998738695
# Word: npac sms shall, Weight: 2.734085545692179
# Word: npac sms, Weight: 1.8555655426898028
# Word: shall be, Weight: 1.7677040495860001
# Word: subscription version, Weight: 1.0318446455781012
# Word: at least, Weight: 0.8645491318246198
# Word: npa split, Weight: 0.691737368926587
# Word: npac personnel, Weight: 0.6348476118467395
# Word: lnp type, Weight: 0.6161697128225649
# Word: will not, Weight: 0.5720779590838011
# Word: not cause, Weight: 0.530888138423951
# Word: have the, Weight: 0.49553405741409073
# Word: equal to, Weight: 0.49254214939503327
# Word: sequence number, Weight: 0.48365466937742985
# Word: their own data, Weight: 0.48089743339539376
# Word: own data, Weight: 0.4806515898148178
# Word: to query, Weight: 0.4803960087370454
# Word: the sender, Weight: 0.47760147901118394
# Word: to support, Weight: 0.47397145678213803
# Word: request and, Weight: 0.4703652403632953
#
# Word: the npac sms, Weight: -1.4567949504411026
# Word: the npac sms will, Weight: -0.45183151953533174
# Word: will be, Weight: -0.41851390119533866
# Word: this document, Weight: -0.376496929935359
# Word: provider network, Weight: -0.344366536707763
# Word: service provider network, Weight: -0.344366536707763
# Word: synchronization of, Weight: -0.2956172463073856
# Word: the new, Weight: -0.28288493123971115
# Word: number portability, Weight: -0.28025708160976803
# Word: this is, Weight: -0.27595591041352074
# Word: download file, Weight: -0.26578969026222815
# Word: that support, Weight: -0.2632037108760291
# Word: functionality and, Weight: -0.2580289102719392
# Word: audit functionality, Weight: -0.257839336022627
# Word: routing information, Weight: -0.2549468345170008
# Word: of the npac sms, Weight: -0.2531199618347354
# Word: service providers to, Weight: -0.25123845132197997
# Word: providers to, Weight: -0.25123845132197997
# Word: functional requirements, Weight: -0.2324632754410502
# Word: npac sms functional, Weight: -0.22820152185919787
#
# Source: inventory-2.0.pdf
# --------------------
# Skipping. Not enough data for a meaningful analysis.
# Source: philips.doc
# --------------------
# Word: the application, Weight: 0.8983814755922961
# Word: passport account, Weight: 0.6697883745808427
# Word: to the, Weight: 0.6075059997155069
# Word: to create, Weight: 0.5947818709903674
# Word: the used, Weight: 0.5451946894208715
# Word: show the, Weight: 0.45516121693110984
# Word: the end users, Weight: 0.445529411906083
# Word: possibility to, Weight: 0.4232373553127029
# Word: the users, Weight: 0.40694569804850383
# Word: users hotmail, Weight: 0.40694569804850383
# Word: the users hotmail, Weight: 0.40694569804850383
# Word: in the, Weight: 0.40563560896460615
# Word: on the screen, Weight: 0.38703609928098814
# Word: the screen, Weight: 0.38703609928098814
# Word: is the, Weight: 0.38087430668682853
# Word: notification when, Weight: 0.3725035244945295
# Word: which the, Weight: 0.35093573559617003
# Word: the buddy, Weight: 0.3434861243402316
# Word: which is, Weight: 0.3255332756530796
# Word: the nickname, Weight: 0.304217834032443
#
# Word: msn messenger, Weight: -0.9851428511422907
# Word: is an, Weight: -0.6232624858589005
# Word: requirements specification, Weight: -0.5949360739500853
# Word: the xlet, Weight: -0.5681920672137881
# Word: buddy list, Weight: -0.5321539828620204
# Word: or other, Weight: -0.45402444251912855
# Word: the msn messenger, Weight: -0.37687188733374816
# Word: the msn, Weight: -0.37687188733374816
# Word: to be, Weight: -0.3491381037640179
# Word: an application, Weight: -0.3331172222876903
# Word: is an application, Weight: -0.3331172222876903
# Word: will be, Weight: -0.29335388980441307
# Word: with the, Weight: -0.2840526135336515
# Word: msn messenger xlet, Weight: -0.21737577212341957
# Word: messenger xlet, Weight: -0.21737577212341957
# Word: the status, Weight: -0.19248526723318335
# Word: the user can, Weight: -0.1897148871554561
# Word: able to, Weight: -0.17429767725967182
# Word: contact list, Weight: -0.1661445863683916
# Word: user can, Weight: -0.1540628745466603
#
# Source: clarus high.doc
# --------------------
# Word: clarus system shall, Weight: 1.488084452422088
# Word: system shall, Weight: 1.4261684332451783
# Word: the clarus system shall, Weight: 1.3306351234495877
# Word: the clarus, Weight: 1.2530365534268897
# Word: the clarus program, Weight: 1.115582260741087
# Word: clarus program, Weight: 1.115582260741087
# Word: program shall, Weight: 0.8400002303785812
# Word: the clarus program shall, Weight: 0.8400002303785812
# Word: clarus program shall, Weight: 0.8400002303785812
# Word: new data sources, Weight: 0.7746566122500634
# Word: shall be, Weight: 0.7355504001046306
# Word: clarus system, Weight: 0.7256194543317438
# Word: data sources, Weight: 0.7169738028259113
# Word: the clarus system, Weight: 0.6977291707268415
# Word: new data, Weight: 0.6499123449154265
# Word: to provide, Weight: 0.41613046812480203
# Word: registered users, Weight: 0.3823766632997815
# Word: access to, Weight: 0.36730737524112106
# Word: access to data, Weight: 0.36191295910677657
# Word: shall be able, Weight: 0.35618231313266935
#
# Word: the data, Weight: -0.46523760212757875
# Word: the system, Weight: -0.4458436724453972
# Word: to the, Weight: -0.360197001904273
# Word: surface transportation, Weight: -0.34346345165458475
# Word: will be, Weight: -0.34165742269229765
# Word: for the, Weight: -0.31410104859746635
# Word: and the, Weight: -0.3012481323601737
# Word: system will, Weight: -0.2641455538707435
# Word: clarus system will, Weight: -0.26285647427366676
# Word: the clarus system will, Weight: -0.26285647427366676
# Word: of data, Weight: -0.253867772758172
# Word: to the clarus, Weight: -0.24751379498009787
# Word: from the, Weight: -0.24686430811132695
# Word: high level, Weight: -0.24660542964419835
# Word: to the clarus system, Weight: -0.22965837426990254
# Word: providers and, Weight: -0.2197462702728365
# Word: clarus initiative, Weight: -0.2172335848362267
# Word: data in, Weight: -0.2148238760837698
# Word: in the, Weight: -0.21014548371415295
# Word: can be, Weight: -0.2070021474148336
#
# Source: library.pdf
# --------------------
# Word: system provides, Weight: 1.2051838304957965
# Word: ability to, Weight: 1.1010744750390613
# Word: system supports, Weight: 0.8181853579759697
# Word: can be, Weight: 0.6605469696156515
# Word: access to, Weight: 0.6366566407805435
# Word: documentation is, Weight: 0.6012386407808333
# Word: staff can, Weight: 0.5846033321479315
# Word: staff and, Weight: 0.4150593480379933
# Word: management tools, Weight: 0.38492132740672413
# Word: staff can view, Weight: 0.3660574766911421
# Word: can view, Weight: 0.3660574766911421
# Word: record types, Weight: 0.3593232506370232
# Word: centrally managed, Weight: 0.3557963237588793
# Word: tables and, Weight: 0.3550383690486143
# Word: and control, Weight: 0.34219971438759894
# Word: such as, Weight: 0.34146193952274256
# Word: loan rules, Weight: 0.34058729358592754
# Word: ip address, Weight: 0.33650476361636883
# Word: check out, Weight: 0.32465444683976086
# Word: to specific, Weight: 0.30896544787749874
#
# Word: system administration, Weight: -1.1752304671895326
# Word: the library, Weight: -0.7700796709192401
# Word: it is, Weight: -0.7271579457246238
# Word: library system, Weight: -0.7072622647525586
# Word: and privileges, Weight: -0.7006974847612606
# Word: system functions, Weight: -0.6288268079035518
# Word: staff who, Weight: -0.6204781444402927
# Word: the system, Weight: -0.6096739173971885
# Word: managers include, Weight: -0.5842745676491465
# Word: requirements for, Weight: -0.5507330146820071
# Word: software developer, Weight: -0.5113696859651977
# Word: high level, Weight: -0.4997715056011326
# Word: software development, Weight: -0.493730948057467
# Word: will be, Weight: -0.4903748205294526
# Word: library services, Weight: -0.473206023831924
# Word: system administration module, Weight: -0.47271569436674876
# Word: administration module, Weight: -0.47271569436674876
# Word: the current, Weight: -0.43026434582812517
# Word: county library, Weight: -0.42935818904951134
# Word: king county, Weight: -0.42935818904951134
#
# Source: peazip.pdf
# --------------------
# Word: and use, Weight: 0.8226860746912448
# Word: installation and use, Weight: 0.8226860746912448
# Word: the only, Weight: 0.6814686012132147
# Word: installation and, Weight: 0.6699652576086416
# Word: this feature, Weight: 0.6204765092977017
# Word: operating system, Weight: 0.5663813564997151
# Word: case of, Weight: 0.531878406201368
# Word: in case of, Weight: 0.531878406201368
# Word: in case, Weight: 0.531878406201368
# Word: for peazip, Weight: 0.4955746133422736
# Word: computer system, Weight: 0.4642079667821048
# Word: of this feature, Weight: 0.44325340602365115
# Word: it can, Weight: 0.41554754159584395
# Word: regardless of, Weight: 0.41554754159584395
# Word: users with, Weight: 0.4060007750937439
# Word: the computer system, Weight: 0.4011067469253903
# Word: the computer, Weight: 0.4011067469253903
# Word: would be, Weight: 0.38229375694703177
# Word: any computer system, Weight: 0.38110522028640104
# Word: any computer, Weight: 0.38110522028640104
#
# Word: is the, Weight: -0.3943756920717814
# Word: concerned peazip, Weight: -0.36888700773687666
# Word: far as, Weight: -0.33368667639936833
# Word: as far, Weight: -0.33368667639936833
# Word: as far as, Weight: -0.33368667639936833
# Word: files and, Weight: -0.3113670694515631
# Word: of peazip, Weight: -0.3053563197775902
# Word: software requirements, Weight: -0.281942800573541
# Word: is concerned, Weight: -0.27631267326563497
# Word: be used, Weight: -0.27174832036864527
# Word: archiving and, Weight: -0.263904986942237
# Word: and compression, Weight: -0.251275295192217
# Word: of any, Weight: -0.24649149927257458
# Word: this software, Weight: -0.23891508504776401
# Word: kind of, Weight: -0.23744816273127525
# Word: software requirements specification, Weight: -0.21413612324996845
# Word: and archive, Weight: -0.21412241518965486
# Word: to any, Weight: -0.21123906666523806
# Word: archiving and compression, Weight: -0.20940736942830376
# Word: application and, Weight: -0.2093246340201862
#
# Source: gparted.pdf
# --------------------
# Word: you can, Weight: 0.9818202996174612
# Word: update and, Weight: 0.7975737871926418
# Word: of the program, Weight: 0.7404508507064012
# Word: and the, Weight: 0.7072167572289607
# Word: that is, Weight: 0.6578544691457834
# Word: to edit, Weight: 0.5962523377865777
# Word: cd dvd, Weight: 0.5639952611874306
# Word: or at, Weight: 0.5625085742516901
# Word: of data, Weight: 0.5567146741506023
# Word: from the, Weight: 0.5529727474905201
# Word: click ok, Weight: 0.5162332202484159
# Word: are not, Weight: 0.514663859650437
# Word: in the, Weight: 0.5000390189327855
# Word: at least, Weight: 0.4935380167270388
# Word: image file, Weight: 0.456608644342722
# Word: loss of data, Weight: 0.43439150284846234
# Word: loss of, Weight: 0.43439150284846234
# Word: as it, Weight: 0.4312095811364569
# Word: to run, Weight: 0.42778609899195014
# Word: have to, Weight: 0.42374803966610497
#
# Word: file systems, Weight: -0.7259115815097812
# Word: disk partitions, Weight: -0.6780643520911138
# Word: file system, Weight: -0.6355434421668334
# Word: this document, Weight: -0.6210315912286117
# Word: with the, Weight: -0.6048770795902818
# Word: your computer, Weight: -0.5240530242684482
# Word: and use, Weight: -0.5232520723268608
# Word: there is, Weight: -0.5217211947902796
# Word: gnu linux, Weight: -0.5177035374370641
# Word: them in, Weight: -0.5065957070209132
# Word: to the, Weight: -0.47327590572992156
# Word: will be, Weight: -0.47202103547755186
# Word: in section, Weight: -0.4586031248272202
# Word: linux operating system, Weight: -0.4583283052387469
# Word: linux operating, Weight: -0.4583283052387469
# Word: such as, Weight: -0.45475871970749476
# Word: for creating, Weight: -0.425664865650067
# Word: operating systems, Weight: -0.4163480174811732
# Word: or delete, Weight: -0.4063338579069576
# Word: the gparted, Weight: -0.39289328668154905
#
# Source: mashboot.pdf
# --------------------
# Word: the system, Weight: 1.8722135382319791
# Word: user account, Weight: 0.9431949490193592
# Word: should have, Weight: 0.8958408536803888
# Word: the following, Weight: 0.8897631939820404
# Word: member should, Weight: 0.851246440941583
# Word: can be, Weight: 0.7577977752306968
# Word: by contributors, Weight: 0.6837530063496948
# Word: mashbot campaigns, Weight: 0.5955969962678037
# Word: should be, Weight: 0.5868636505784817
# Word: performed by, Weight: 0.5467750598662351
# Word: to an, Weight: 0.5398215949317268
# Word: the system administrator, Weight: 0.509605824667172
# Word: system administrator, Weight: 0.509605824667172
# Word: pieces of, Weight: 0.5037292230656284
# Word: campaigns should, Weight: 0.4296314494083038
# Word: multiple users, Weight: 0.4296314494083038
# Word: account roles, Weight: 0.42061187423624546
# Word: should be able, Weight: 0.4202928310113464
# Word: should be able to, Weight: 0.4202928310113464
# Word: more than, Weight: 0.40425705423792474
#
# Word: these requirements, Weight: -1.0464517425524293
# Word: to be, Weight: -0.7784320236381332
# Word: customer service, Weight: -0.7178373403717657
# Word: will be, Weight: -0.7150986535215289
# Word: to the, Weight: -0.710955171778192
# Word: the user, Weight: -0.688338327749422
# Word: the mashbot, Weight: -0.6745177644011267
# Word: to provide, Weight: -0.6269735335602827
# Word: will also, Weight: -0.586045120693347
# Word: is to, Weight: -0.5362214010804145
# Word: with the, Weight: -0.4999850692555166
# Word: social media, Weight: -0.49510415445356326
# Word: authentication mashbot, Weight: -0.4817263145016816
# Word: for various, Weight: -0.4713691565699683
# Word: mashbot is, Weight: -0.4489401084515051
# Word: web application, Weight: -0.43528827984268054
# Word: platform will, Weight: -0.42666157641973707
# Word: there is, Weight: -0.4037339417859594
# Word: on social, Weight: -0.38391179425845584
# Word: existing service, Weight: -0.38237001284465844
#
# Source: split merge.pdf
# --------------------
# Word: the application, Weight: 1.040661992152305
# Word: must be, Weight: 0.851829322268295
# Word: is not, Weight: 0.6829132587202398
# Word: the user, Weight: 0.6488836933572999
# Word: the project, Weight: 0.6413163001691456
# Word: check for, Weight: 0.6253095364835616
# Word: to use, Weight: 0.6162292386274941
# Word: the computer system, Weight: 0.5820909945186696
# Word: system on, Weight: 0.5820909945186696
# Word: the computer, Weight: 0.5820909945186696
# Word: to provide, Weight: 0.5713207447276047
# Word: in the, Weight: 0.5669945916973558
# Word: or less, Weight: 0.4947219669414162
# Word: with every, Weight: 0.48778057000575314
# Word: to be, Weight: 0.4787722227241702
# Word: help messages, Weight: 0.4741359229827918
# Word: in this, Weight: 0.46908542151457683
# Word: pdfsam is, Weight: 0.4640735668034579
# Word: computer system, Weight: 0.4405260031746458
# Word: at time, Weight: 0.42898101238772246
#
# Word: of the, Weight: -0.6490878785753168
# Word: this document, Weight: -0.551974844058974
# Word: this project, Weight: -0.5498550044805429
# Word: to handle, Weight: -0.5331583340470042
# Word: it is, Weight: -0.5156468727718576
# Word: is the, Weight: -0.44732066736646725
# Word: open source, Weight: -0.4342902510477756
# Word: who can, Weight: -0.4220173916667396
# Word: pdf document, Weight: -0.3464225488336898
# Word: is platform, Weight: -0.3303351596983271
# Word: is platform independent, Weight: -0.3303351596983271
# Word: platform independent, Weight: -0.3303351596983271
# Word: program to, Weight: -0.3290594552531327
# Word: it provides, Weight: -0.32815818377992145
# Word: the basic, Weight: -0.32456560203984774
# Word: selected pdf, Weight: -0.31079753545903427
# Word: of the project, Weight: -0.30910017176050697
# Word: and it, Weight: -0.29609044997835804
# Word: the pdfsam, Weight: -0.28870697362518977
# Word: file format, Weight: -0.2869177242139346
#
# Source: e-store.doc
# --------------------
# Word: shall be, Weight: 1.2665532990110062
# Word: the system, Weight: 1.246183420085588
# Word: system shall, Weight: 1.2211995953039945
# Word: the system shall, Weight: 0.956105115397931
# Word: the product, Weight: 0.5888323946007564
# Word: there are, Weight: 0.5403440642294313
# Word: the client, Weight: 0.5118843288880554
# Word: display the, Weight: 0.41909101869683146
# Word: will be, Weight: 0.37748718758978494
# Word: and product, Weight: 0.350929921230304
# Word: must be, Weight: 0.3502404471710262
# Word: components of the, Weight: 0.34926664388709106
# Word: components of, Weight: 0.34926664388709106
# Word: shall provide, Weight: 0.3367746684186415
# Word: it shall, Weight: 0.33609428249355067
# Word: use the, Weight: 0.32097576512194015
# Word: software system, Weight: 0.3101864431557031
# Word: shall communicate, Weight: 0.29066593202714275
# Word: store system, Weight: 0.26318395127299954
# Word: the store system, Weight: 0.26318395127299954
#
# Word: and its, Weight: -0.6090298061652698
# Word: functional requirements, Weight: -0.6004698493990865
# Word: of the, Weight: -0.5479921349417913
# Word: this document, Weight: -0.5313569603492712
# Word: can be, Weight: -0.5118370921721506
# Word: stakeholders and, Weight: -0.43324625416245294
# Word: requirements of, Weight: -0.4239272385835539
# Word: product features, Weight: -0.42110120073917645
# Word: the following, Weight: -0.40507571612598553
# Word: it also, Weight: -0.3928400515593844
# Word: the detail product, Weight: -0.3796023332537452
# Word: the detail, Weight: -0.3796023332537452
# Word: detail product, Weight: -0.3796023332537452
# Word: description of, Weight: -0.3735282837260048
# Word: gives the, Weight: -0.36694140889271065
# Word: assist in, Weight: -0.35832773787876915
# Word: to assist in, Weight: -0.35832773787876915
# Word: to assist, Weight: -0.35832773787876915
# Word: be used, Weight: -0.3438855318534581
# Word: the stakeholders, Weight: -0.3377976353177718
#
# Source: viper.doc
# --------------------
# Word: the system, Weight: 1.5414390790135366
# Word: page contain, Weight: 1.0799450666040196
# Word: user can, Weight: 0.9444193512020229
# Word: customer supplier, Weight: 0.8360802871583002
# Word: will use, Weight: 0.6862537781931474
# Word: system will, Weight: 0.6658710065994764
# Word: the user, Weight: 0.6320287586266595
# Word: list box, Weight: 0.6069777446845752
# Word: through pages, Weight: 0.596070417704148
# Word: does not, Weight: 0.5595535189327221
# Word: his her, Weight: 0.5281867647574381
# Word: coordinator costumer, Weight: 0.4793278117205519
# Word: interact with, Weight: 0.4771599998370804
# Word: can be, Weight: 0.46603592294654234
# Word: this page, Weight: 0.44731532760913933
# Word: our system will, Weight: 0.4334883487515461
# Word: to the, Weight: 0.4297288000774881
# Word: click on, Weight: 0.4278925209626627
# Word: system will use, Weight: 0.42685378800930124
# Word: our system, Weight: 0.38512993914495613
#
# Word: the srs, Weight: -0.5700383531202081
# Word: and the, Weight: -0.5352670073603347
# Word: management process, Weight: -0.48667706897813856
# Word: the system has, Weight: -0.44174170414249103
# Word: system has, Weight: -0.44174170414249103
# Word: and suppliers, Weight: -0.4411918554720892
# Word: we must, Weight: -0.4054018320676337
# Word: that we, Weight: -0.3883629494751321
# Word: our scm, Weight: -0.375009025325351
# Word: maintain customer, Weight: -0.36935683888326304
# Word: organization and, Weight: -0.36344289700875504
# Word: into the, Weight: -0.35514841488289495
# Word: supply chain, Weight: -0.3381772252491442
# Word: which include, Weight: -0.32139803996875627
# Word: the first, Weight: -0.31591257419162694
# Word: srs document, Weight: -0.3096155381877736
# Word: customer service, Weight: -0.3075211199610344
# Word: the same, Weight: -0.2853395979817726
# Word: and the system, Weight: -0.27679000664692005
# Word: and the system will, Weight: -0.27679000664692005
#
# Source: virtual ed.doc
# --------------------
# Word: must be, Weight: 1.065332695652082
# Word: the user, Weight: 1.0292698742830266
# Word: the use, Weight: 0.9709304381881785
# Word: conferencing feature, Weight: 0.8413010242234088
# Word: should be, Weight: 0.8069454080239609
# Word: and adobe, Weight: 0.7355277892025023
# Word: the portal, Weight: 0.7028529854966508
# Word: web conferencing, Weight: 0.6696600172658322
# Word: the system, Weight: 0.6367071922677873
# Word: in the, Weight: 0.6133021563329595
# Word: the content, Weight: 0.5855819692056542
# Word: and federal, Weight: 0.5735502505903806
# Word: state and, Weight: 0.5735502505903806
# Word: state and federal, Weight: 0.5735502505903806
# Word: used for, Weight: 0.5439283849655239
# Word: on the, Weight: 0.543516775599508
# Word: the conferencing feature, Weight: 0.5233696053545438
# Word: the conferencing, Weight: 0.5233696053545438
# Word: the local, Weight: 0.519531906254275
# Word: users to, Weight: 0.5043446190243016
#
# Word: virtual edu, Weight: -0.6988300488866042
# Word: will have, Weight: -0.4211927715111571
# Word: the same, Weight: -0.40018774149997755
# Word: users will, Weight: -0.38170237089676445
# Word: this document, Weight: -0.37676480295830067
# Word: will also, Weight: -0.3502347153220131
# Word: on demand, Weight: -0.3473936244653665
# Word: entire system, Weight: -0.3353658818848215
# Word: file sharing, Weight: -0.31558164184185333
# Word: access to, Weight: -0.3121001996705951
# Word: need to be, Weight: -0.30501930928977405
# Word: need to, Weight: -0.30501930928977405
# Word: need for, Weight: -0.30433208632331
# Word: functional requirements, Weight: -0.300321609855384
# Word: the university, Weight: -0.29517025243390427
# Word: 000 000, Weight: -0.2928970242506436
# Word: requirements will be, Weight: -0.29250488240198214
# Word: requirements will, Weight: -0.29250488240198214
# Word: user profiles, Weight: -0.2896329112738302
# Word: requirements that, Weight: -0.2840540695841965
#
# Source: 2009 - library.doc
# --------------------
# Word: ability to, Weight: 1.1225787745391527
# Word: system provides, Weight: 1.1093735515875376
# Word: the system, Weight: 1.0911810988411152
# Word: can be, Weight: 0.7340058886232357
# Word: should be, Weight: 0.6879397332670937
# Word: in the, Weight: 0.6335505680683845
# Word: check outs, Weight: 0.5923629434146807
# Word: reports and, Weight: 0.5438235390097017
# Word: example staff, Weight: 0.5320898872818581
# Word: transactions are, Weight: 0.5281362024853948
# Word: by type, Weight: 0.5145898843213949
# Word: for example, Weight: 0.5105850922606057
# Word: based on, Weight: 0.4468199645936949
# Word: the results, Weight: 0.44035103046237717
# Word: the system provides, Weight: 0.4213476748107095
# Word: item records, Weight: 0.41218868737514686
# Word: grouped by, Weight: 0.403838262957709
# Word: can create, Weight: 0.403257552862287
# Word: per library, Weight: 0.4018413822316488
# Word: line staff, Weight: 0.39687456412166056
#
# Word: management processes, Weight: -1.2432635985621472
# Word: it is, Weight: -0.5238291659520256
# Word: of the, Weight: -0.5025927059434875
# Word: for all, Weight: -0.47259607308182605
# Word: the library, Weight: -0.44502991869563535
# Word: pines library, Weight: -0.43334447919781477
# Word: software development, Weight: -0.42783855781291386
# Word: list of, Weight: -0.42471837343348534
# Word: system functions, Weight: -0.42454167341481774
# Word: the current, Weight: -0.40902557995175093
# Word: needed for, Weight: -0.3982416288687823
# Word: reports working, Weight: -0.3895071397476839
# Word: reports working group, Weight: -0.3895071397476839
# Word: working group, Weight: -0.3895071397476839
# Word: staff who, Weight: -0.3889489507089067
# Word: library card, Weight: -0.383535622438514
# Word: analyzing the, Weight: -0.37108637443330733
# Word: pines reports, Weight: -0.3628106421798508
# Word: system administrators, Weight: -0.36154627962377583
# Word: management processes shall, Weight: -0.36071758285885364
#
# Source: inventory 2.0.pdf
# --------------------
# Skipping. Not enough data for a meaningful analysis.

# %%
ling_words
# Out:
# {'cctns.pdf': ([('should be', np.float64(1.4157989627847516)),
#    ('the system', np.float64(0.9880781162690828)),
#    ('system should', np.float64(0.5586876624983365)),
#    ('the system should', np.float64(0.5586876624983365)),
#    ('the user', np.float64(0.5332939247621353)),
#    ('the system must', np.float64(0.4260760082279166)),
#    ('system must', np.float64(0.4260760082279166)),
#    ('iso 9241', np.float64(0.41643844850799244)),
#    ('in the', np.float64(0.37397087480479163)),
#    ('to be', np.float64(0.31396944643602964)),
#    ('to the', np.float64(0.27195057509459514)),
#    ('use of', np.float64(0.25372232275782)),
#    ('does not', np.float64(0.24451890650815353)),
#    ('must be', np.float64(0.2394118480426658)),
#    ('the same', np.float64(0.23352051299622414)),
#    ('solution should', np.float64(0.22184496607396428)),
#    ('to allow', np.float64(0.2059591329123451)),
#    ('the solution should', np.float64(0.20326315681050233)),
#    ('the solution', np.float64(0.20326315681050233)),
#    ('should be provided', np.float64(0.198557563954228))],
#   [('of the', np.float64(-0.8658616679178002)),
#    ('the core', np.float64(-0.6450682996755209)),
#    ('based on', np.float64(-0.620453659984847)),
#    ('functional architecture', np.float64(-0.5907271443447385)),
#    ('police and', np.float64(-0.576643785523306)),
#    ('the cctns', np.float64(-0.5530886937054229)),
#    ('with the courts', np.float64(-0.5469147481332791)),
#    ('the courts', np.float64(-0.5469147481332791)),
#    ('the functional', np.float64(-0.5168157594552764)),
#    ('of the cctns', np.float64(-0.5118253185515264)),
#    ('the guiding', np.float64(-0.511117247097662)),
#    ('based on the', np.float64(-0.49569367220140026)),
#    ('each of', np.float64(-0.4861774805176833)),
#    ('each of the', np.float64(-0.4861774805176833)),
#    ('the investigation', np.float64(-0.480169201683027)),
#    ('with the', np.float64(-0.47239659491645836)),
#    ('the investigation process', np.float64(-0.4683426583974745)),
#    ('investigation process', np.float64(-0.4683426583974745)),
#    ('architecture is', np.float64(-0.4495058672116233)),
#    ('functional architecture is', np.float64(-0.4495058672116233))]),
#  'dii.htm': ([('shall be', np.float64(1.5947376704664893)),
#    ('the xs', np.float64(1.5645475428458588)),
#    ('mode this', np.float64(0.9865474317759844)),
#    ('services shall', np.float64(0.8853346186816241)),
#    ('xs shall', np.float64(0.8759338010818832)),
#    ('the xs shall', np.float64(0.8759338010818832)),
#    ('session time', np.float64(0.8084584632275852)),
#    ('data management', np.float64(0.753182137458903)),
#    ('and or', np.float64(0.702235909832838)),
#    ('other related', np.float64(0.6914477096846592)),
#    ('software shall be', np.float64(0.6723796344820147)),
#    ('precedence and', np.float64(0.6337162527601337)),
#    ('precedence and criticality', np.float64(0.6337162527601337)),
#    ('and criticality', np.float64(0.6337162527601337)),
#    ('level requirements', np.float64(0.63328596098457)),
#    ('the rts', np.float64(0.6279855211892155)),
#    ('in the rts', np.float64(0.6279855211892155)),
#    ('management services', np.float64(0.6216155823409639)),
#    ('data management services', np.float64(0.6216155823409639)),
#    ('in addition', np.float64(0.6198531057084753))],
#   [('information resources', np.float64(-0.36782043881763654)),
#    ('information resource', np.float64(-0.36437889561942066)),
#    ('for the', np.float64(-0.29928108552440236)),
#    ('of xml', np.float64(-0.29018419630187475)),
#    ('outlines the', np.float64(-0.23885519373169017)),
#    ('database management', np.float64(-0.1954419287372131)),
#    ('the information', np.float64(-0.19306320118936812)),
#    ('and control', np.float64(-0.19074941238681456)),
#    ('to an', np.float64(-0.1751304587894452)),
#    ('and verification', np.float64(-0.1747561918483649)),
#    ('xml tags', np.float64(-0.1716039751516861)),
#    ('command and control', np.float64(-0.17005666405482678)),
#    ('command and', np.float64(-0.17005666405482678)),
#    ('data is', np.float64(-0.16985378470741372)),
#    ('the coe', np.float64(-0.168033817178999)),
#    ('capability to', np.float64(-0.16543550712300556)),
#    ('these services', np.float64(-0.1623454985803315)),
#    ('tags and', np.float64(-0.1582443090666025)),
#    ('the software', np.float64(-0.15726022777006451)),
#    ('an xml', np.float64(-0.15497309825954186))]),
#  'gamma j.pdf': ([('the system', np.float64(1.3621414240964314)),
#    ('system shall', np.float64(1.3190001311914579)),
#    ('the system shall', np.float64(1.178414079810777)),
#    ('will be', np.float64(1.0110252452214874)),
#    ('customer profiles', np.float64(0.7636863565160111)),
#    ('the specific', np.float64(0.6192238017630133)),
#    ('the system will', np.float64(0.5841263587982428)),
#    ('be able to', np.float64(0.5662311254977781)),
#    ('be able', np.float64(0.5662311254977781)),
#    ('shall be', np.float64(0.5550354355508331)),
#    ('internet connection', np.float64(0.5409535286195915)),
#    ('with the', np.float64(0.48972254440056406)),
#    ('will also', np.float64(0.48480950790156463)),
#    ('customer will', np.float64(0.47660281055973336)),
#    ('the customer will', np.float64(0.47660281055973336)),
#    ('credit card', np.float64(0.4641043318785845)),
#    ('of items', np.float64(0.45196798678102906)),
#    ('the inventory management', np.float64(0.4232485911100819)),
#    ('inventory management', np.float64(0.4232485911100819)),
#    ('through programmatic interface', np.float64(0.40692382311133596))],
#   [('of the', np.float64(-0.8704387405477236)),
#    ('web store', np.float64(-0.7090202713500172)),
#    ('the administrator', np.float64(-0.4937576906425929)),
#    ('store inventory', np.float64(-0.4029264252446687)),
#    ('yoggie corporation', np.float64(-0.3928656018963748)),
#    ('system to', np.float64(-0.3924708327121366)),
#    ('high priority', np.float64(-0.3828003725705149)),
#    ('description of', np.float64(-0.3501929765389615)),
#    ('the requirements', np.float64(-0.3492796141910356)),
#    ('the web', np.float64(-0.34850193889183834)),
#    ('sql based', np.float64(-0.34526468158727214)),
#    ('sql based database', np.float64(-0.34526468158727214)),
#    ('based database', np.float64(-0.34526468158727214)),
#    ('use sql based database', np.float64(-0.34526468158727214)),
#    ('use sql based', np.float64(-0.34526468158727214)),
#    ('use sql', np.float64(-0.34526468158727214)),
#    ('of system', np.float64(-0.3238090259643086)),
#    ('be in', np.float64(-0.3096462851788196)),
#    ('to ensure', np.float64(-0.30890408127232)),
#    ('functional requirements', np.float64(-0.30637196788726256))]),
#  'inventory.pdf': ([('it is', np.float64(0.9792894387639592)),
#    ('administrative level', np.float64(0.9135032291564893)),
#    ('member can', np.float64(0.846582029173304)),
#    ('application should', np.float64(0.7620371902376639)),
#    ('backup operation', np.float64(0.6463816087922709)),
#    ('group member', np.float64(0.6196538483472238)),
#    ('the application', np.float64(0.595227919487366)),
#    ('request is', np.float64(0.5682980749326415)),
#    ('an inventory', np.float64(0.4975911670972654)),
#    ('any administrative level', np.float64(0.4787798176940993)),
#    ('approved by', np.float64(0.44816171505258623)),
#    ('should be', np.float64(0.44656774403249416)),
#    ('more than', np.float64(0.4319789434018874)),
#    ('when user', np.float64(0.41525778147461745)),
#    ('user according to', np.float64(0.40447424388566505)),
#    ('user according', np.float64(0.40447424388566505)),
#    ('be approved by', np.float64(0.39854042516243404)),
#    ('be approved', np.float64(0.39854042516243404)),
#    ('by user name', np.float64(0.3713309281076743)),
#    ('by user name and', np.float64(0.3713309281076743))],
#   [('inventory admin', np.float64(-0.9706619051509673)),
#    ('use case', np.float64(-0.7770473773335315)),
#    ('the following', np.float64(-0.6419451906711997)),
#    ('request form', np.float64(-0.48296961799313803)),
#    ('the inventory', np.float64(-0.4633535173922632)),
#    ('is displayed', np.float64(-0.42167793310440643)),
#    ('interface that', np.float64(-0.4057501212028405)),
#    ('the use case', np.float64(-0.4007800915442289)),
#    ('the use', np.float64(-0.4007800915442289)),
#    ('message error', np.float64(-0.3781536956673234)),
#    ('the system', np.float64(-0.3778205039958439)),
#    ('on the', np.float64(-0.37700224482665756)),
#    ('request to', np.float64(-0.3628089917049737)),
#    ('user select', np.float64(-0.3505698602443147)),
#    ('user enter', np.float64(-0.3444825370829912)),
#    ('use case begins', np.float64(-0.33521187274205017)),
#    ('case begins', np.float64(-0.33521187274205017)),
#    ('inventory system', np.float64(-0.3341687034539213)),
#    ('the iufa', np.float64(-0.3093194073861154)),
#    ('any time', np.float64(-0.3093194073861154))]),
#  'multi-mahjong.pdf': ([('will be', np.float64(1.3715817106142723)),
#    ('the user', np.float64(1.1539474291587364)),
#    ('multimahjongserver will', np.float64(0.9797487911047145)),
#    ('the multimahjongserver will', np.float64(0.9797487911047145)),
#    ('unix box', np.float64(0.9291206197215848)),
#    ('the multimahjongserver', np.float64(0.8853516027145115)),
#    ('multi player', np.float64(0.7864514387090586)),
#    ('multimahjongclient will', np.float64(0.7615771271856723)),
#    ('the multimahjongclient will', np.float64(0.7566165726679255)),
#    ('program execution', np.float64(0.6989794117956805)),
#    ('option to', np.float64(0.6014129616967306)),
#    ('be able', np.float64(0.5670794114801041)),
#    ('be able to', np.float64(0.5670794114801041)),
#    ('multimahjongclient must', np.float64(0.5622266084286937)),
#    ('in the', np.float64(0.5548539296438212)),
#    ('another player', np.float64(0.5540030627002226)),
#    ('capable of', np.float64(0.5319087269133506)),
#    ('able to', np.float64(0.523578306177497)),
#    ('users who', np.float64(0.5179054568335938)),
#    ('the co', np.float64(0.5147331454478815))],
#   [('the client', np.float64(-0.4207443139863226)),
#    ('the project', np.float64(-0.4201611887804735)),
#    ('main window', np.float64(-0.3867264752035359)),
#    ('and the', np.float64(-0.34837009667940416)),
#    ('by the', np.float64(-0.3433835669090743)),
#    ('the multimahjongclient program', np.float64(-0.3326372506035459)),
#    ('multimahjongclient program', np.float64(-0.3326372506035459)),
#    ('multimahjong is', np.float64(-0.3294791582832765)),
#    ('to play', np.float64(-0.3240466941609359)),
#    ('this document', np.float64(-0.31865803874132226)),
#    ('for the', np.float64(-0.31514823594965696)),
#    ('runs the', np.float64(-0.29468742782435986)),
#    ('set of', np.float64(-0.285837095576471)),
#    ('in this', np.float64(-0.2759417752257522)),
#    ('the other', np.float64(-0.26487665545414424)),
#    ('multimahjongserver is to', np.float64(-0.2630678860767527)),
#    ('multimahjongserver is', np.float64(-0.2630678860767527)),
#    ('the multimahjongserver is', np.float64(-0.2630678860767527)),
#    ('the multimahjongserver is to', np.float64(-0.2630678860767527)),
#    ('game and', np.float64(-0.2557264282263557))]),
#  'beyond.pdf': ([('the system', np.float64(0.7876591087383612)),
#    ('the ui', np.float64(0.6105436622405583)),
#    ('user interface', np.float64(0.5687615879730853)),
#    ('and the', np.float64(0.5262452938659955)),
#    ('should be', np.float64(0.5070779972026085)),
#    ('the firmware', np.float64(0.48461793129551256)),
#    ('the user', np.float64(0.44865078327912566)),
#    ('provide the', np.float64(0.43302631692565174)),
#    ('are not', np.float64(0.4281022103477934)),
#    ('because of', np.float64(0.4279025643908396)),
#    ('is an', np.float64(0.4228576594267923)),
#    ('the authoring tool', np.float64(0.42122695715002)),
#    ('the authoring', np.float64(0.42122695715002)),
#    ('authoring tool', np.float64(0.42122695715002)),
#    ('functionality we', np.float64(0.3999191905582257)),
#    ('this is', np.float64(0.39503853359818103)),
#    ('be implemented', np.float64(0.38776416222604937)),
#    ('must be', np.float64(0.3828704029882512)),
#    ('specifications are', np.float64(0.38248577461627464)),
#    ('the terminal', np.float64(0.3724588713205577))],
#   [('have been', np.float64(-0.9298910230844633)),
#    ('there are', np.float64(-0.6786635975978178)),
#    ('project are', np.float64(-0.6408192428254206)),
#    ('and d8', np.float64(-0.6290902003657596)),
#    ('the project', np.float64(-0.6255521409878965)),
#    ('the contributions', np.float64(-0.6225584416351109)),
#    ('these aspects', np.float64(-0.6054529635029563)),
#    ('this document', np.float64(-0.6039061138201094)),
#    ('architectural issues', np.float64(-0.599013341167613)),
#    ('that the', np.float64(-0.5914712669418233)),
#    ('common deliverable', np.float64(-0.5776066110436584)),
#    ('the same', np.float64(-0.5662183670073173)),
#    ('that are', np.float64(-0.5220012800255734)),
#    ('the second', np.float64(-0.5110545960905566)),
#    ('in this', np.float64(-0.49606610046374094)),
#    ('in particular', np.float64(-0.49192366520303277)),
#    ('functional specifications', np.float64(-0.4718803184642796)),
#    ('it is', np.float64(-0.4711081589626372)),
#    ('has been', np.float64(-0.4619129380231218)),
#    ('this deliverable', np.float64(-0.46045780545016374))]),
#  'elsfork.pdf': ([('shall be', np.float64(1.7026783025884802)),
#    ('condition monitoring', np.float64(0.8174919250368706)),
#    ('the communication', np.float64(0.8133397338759047)),
#    ('scanning rate', np.float64(0.754657879406815)),
#    ('could be', np.float64(0.7490097276714194)),
#    ('at least', np.float64(0.7386724492396028)),
#    ('transport media', np.float64(0.7362954661568386)),
#    ('the physical', np.float64(0.7279618489455256)),
#    ('the communication system', np.float64(0.7080489287475323)),
#    ('functions and', np.float64(0.7005005906005891)),
#    ('may also', np.float64(0.69012999433237)),
#    ('data as', np.float64(0.6742233156931395)),
#    ('the following', np.float64(0.6559131674797126)),
#    ('and procedures', np.float64(0.6298901949773134)),
#    ('of programs', np.float64(0.6089763492277097)),
#    ('time critical', np.float64(0.606147904088994)),
#    ('time critical functions', np.float64(0.606147904088994)),
#    ('critical functions', np.float64(0.606147904088994)),
#    ('may be', np.float64(0.6011463505500304)),
#    ('standards and procedures', np.float64(0.5991023150587685))],
#   [('wind farm', np.float64(-0.7773356931508631)),
#    ('the specification', np.float64(-0.7561849317138732)),
#    ('used to', np.float64(-0.6585659178060113)),
#    ('the different', np.float64(-0.6527674135690588)),
#    ('iec 61850', np.float64(-0.6523841774763633)),
#    ('the requirements', np.float64(-0.5450930894059722)),
#    ('to the', np.float64(-0.5366238474230328)),
#    ('communication network', np.float64(-0.5214373783560571)),
#    ('iec 60870', np.float64(-0.5165952796758563)),
#    ('the wind farm', np.float64(-0.5155852415216623)),
#    ('or more', np.float64(-0.5065751137577789)),
#    ('control of', np.float64(-0.49816194729176105)),
#    ('functions are', np.float64(-0.4914642970864054)),
#    ('there are', np.float64(-0.4861676178313255)),
#    ('for an', np.float64(-0.4796743334574763)),
#    ('by the', np.float64(-0.46075124022781816)),
#    ('stands for', np.float64(-0.46029134457211474)),
#    ('control system', np.float64(-0.4600611715955715)),
#    ('data objects', np.float64(-0.44969400757653505)),
#    ('there is', np.float64(-0.444272198502155))]),
#  'esa.pdf': ([('shall be', np.float64(1.2888987875804163)),
#    ('the apaf', np.float64(0.8341902822587284)),
#    ('swri shall', np.float64(0.614067858204486)),
#    ('swri shall provide', np.float64(0.5646880183599883)),
#    ('shall provide', np.float64(0.5646880183599883)),
#    ('system shall', np.float64(0.522157831875053)),
#    ('apaf system', np.float64(0.510731317235109)),
#    ('there are no', np.float64(0.44714026617538993)),
#    ('are no', np.float64(0.44714026617538993)),
#    ('the apaf system', np.float64(0.4310089325225689)),
#    ('there shall', np.float64(0.38737641075765844)),
#    ('there shall be', np.float64(0.38737641075765844)),
#    ('of the apaf', np.float64(0.32484124683803056)),
#    ('the apaf system shall', np.float64(0.32273228267127096)),
#    ('apaf system shall', np.float64(0.32273228267127096)),
#    ('aspera data', np.float64(0.32040486111453753)),
#    ('ap af', np.float64(0.3115114150206018)),
#    ('af system', np.float64(0.3115114150206018)),
#    ('ap af system', np.float64(0.3115114150206018)),
#    ('science analysis', np.float64(0.30940973489802176))],
#   [('each requirement', np.float64(-0.5469747898294478)),
#    ('of the', np.float64(-0.5062853116004444)),
#    ('will be', np.float64(-0.4125212091286468)),
#    ('is to', np.float64(-0.39525420574516507)),
#    ('requirement is', np.float64(-0.3639293816410895)),
#    ('requirement may', np.float64(-0.36299468775283505)),
#    ('number of', np.float64(-0.3147977544720062)),
#    ('and archiving', np.float64(-0.3135103879744279)),
#    ('from the', np.float64(-0.2916500595740599)),
#    ('data system', np.float64(-0.29040544413817454)),
#    ('each requirement shall', np.float64(-0.280710038390544)),
#    ('each requirement shall be', np.float64(-0.280710038390544)),
#    ('requirement shall', np.float64(-0.280710038390544)),
#    ('requirement shall be', np.float64(-0.280710038390544)),
#    ('in section', np.float64(-0.2708153436731503)),
#    ('in form', np.float64(-0.2515615556671679)),
#    ('that will', np.float64(-0.23735766768590122)),
#    ('data products', np.float64(-0.2367013856076412)),
#    ('data sets', np.float64(-0.23005389404220786)),
#    ('the requirements', np.float64(-0.22009274865276351))]),
#  'libra.doc': ([('should be', np.float64(0.9335168106909659)),
#    ('should provide', np.float64(0.7758370900800022)),
#    ('the cluster', np.float64(0.7724546805276968)),
#    ('the maximum', np.float64(0.7123367441721028)),
#    ('be done', np.float64(0.706524550364165)),
#    ('will be', np.float64(0.6750168894165907)),
#    ('the job', np.float64(0.6362682647795718)),
#    ('this feature', np.float64(0.5732872580256306)),
#    ('cluster information', np.float64(0.528227428346593)),
#    ('will not', np.float64(0.4975552959439587)),
#    ('by sge', np.float64(0.4833641546660277)),
#    ('of sge', np.float64(0.46457792152898375)),
#    ('may be', np.float64(0.45804055746428146)),
#    ('able to', np.float64(0.4560045052295674)),
#    ('the scheduler', np.float64(0.4556605004959682)),
#    ('and scheduling', np.float64(0.4547909426616385)),
#    ('host and queue', np.float64(0.44518952753105956)),
#    ('host and', np.float64(0.44518952753105956)),
#    ('and queue', np.float64(0.44518952753105956)),
#    ('to the user', np.float64(0.4350484574051331))],
#   [('is the', np.float64(-0.5633959095755406)),
#    ('will be used', np.float64(-0.5304185235935857)),
#    ('the resource', np.float64(-0.4786051935719139)),
#    ('high performance', np.float64(-0.4733895275227199)),
#    ('by the user', np.float64(-0.45006256117415006)),
#    ('freely available', np.float64(-0.4298439341738784)),
#    ('cpu utilization', np.float64(-0.423447325291451)),
#    ('to optimize', np.float64(-0.423447325291451)),
#    ('to the', np.float64(-0.41334023920629115)),
#    ('of the scheduler', np.float64(-0.40851317509563057)),
#    ('the srs', np.float64(-0.4066285487162396)),
#    ('as the', np.float64(-0.40351996665304235)),
#    ('as they', np.float64(-0.40163013367369854)),
#    ('they are', np.float64(-0.37583441052771677)),
#    ('is an', np.float64(-0.3678248611736261)),
#    ('users for', np.float64(-0.36246827271366194)),
#    ('system the', np.float64(-0.35248679696297114)),
#    ('the same', np.float64(-0.35130534193238117)),
#    ('the process', np.float64(-0.3495078136178238)),
#    ('provided in', np.float64(-0.34132435008056666))]),
#  'npac.doc': ([('sms shall', np.float64(2.781964998738695)),
#    ('npac sms shall', np.float64(2.734085545692179)),
#    ('npac sms', np.float64(1.8555655426898028)),
#    ('shall be', np.float64(1.7677040495860001)),
#    ('subscription version', np.float64(1.0318446455781012)),
#    ('at least', np.float64(0.8645491318246198)),
#    ('npa split', np.float64(0.691737368926587)),
#    ('npac personnel', np.float64(0.6348476118467395)),
#    ('lnp type', np.float64(0.6161697128225649)),
#    ('will not', np.float64(0.5720779590838011)),
#    ('not cause', np.float64(0.530888138423951)),
#    ('have the', np.float64(0.49553405741409073)),
#    ('equal to', np.float64(0.49254214939503327)),
#    ('sequence number', np.float64(0.48365466937742985)),
#    ('their own data', np.float64(0.48089743339539376)),
#    ('own data', np.float64(0.4806515898148178)),
#    ('to query', np.float64(0.4803960087370454)),
#    ('the sender', np.float64(0.47760147901118394)),
#    ('to support', np.float64(0.47397145678213803)),
#    ('request and', np.float64(0.4703652403632953))],
#   [('the npac sms', np.float64(-1.4567949504411026)),
#    ('the npac sms will', np.float64(-0.45183151953533174)),
#    ('will be', np.float64(-0.41851390119533866)),
#    ('this document', np.float64(-0.376496929935359)),
#    ('provider network', np.float64(-0.344366536707763)),
#    ('service provider network', np.float64(-0.344366536707763)),
#    ('synchronization of', np.float64(-0.2956172463073856)),
#    ('the new', np.float64(-0.28288493123971115)),
#    ('number portability', np.float64(-0.28025708160976803)),
#    ('this is', np.float64(-0.27595591041352074)),
#    ('download file', np.float64(-0.26578969026222815)),
#    ('that support', np.float64(-0.2632037108760291)),
#    ('functionality and', np.float64(-0.2580289102719392)),
#    ('audit functionality', np.float64(-0.257839336022627)),
#    ('routing information', np.float64(-0.2549468345170008)),
#    ('of the npac sms', np.float64(-0.2531199618347354)),
#    ('service providers to', np.float64(-0.25123845132197997)),
#    ('providers to', np.float64(-0.25123845132197997)),
#    ('functional requirements', np.float64(-0.2324632754410502)),
#    ('npac sms functional', np.float64(-0.22820152185919787))]),
#  'philips.doc': ([('the application', np.float64(0.8983814755922961)),
#    ('passport account', np.float64(0.6697883745808427)),
#    ('to the', np.float64(0.6075059997155069)),
#    ('to create', np.float64(0.5947818709903674)),
#    ('the used', np.float64(0.5451946894208715)),
#    ('show the', np.float64(0.45516121693110984)),
#    ('the end users', np.float64(0.445529411906083)),
#    ('possibility to', np.float64(0.4232373553127029)),
#    ('the users', np.float64(0.40694569804850383)),
#    ('users hotmail', np.float64(0.40694569804850383)),
#    ('the users hotmail', np.float64(0.40694569804850383)),
#    ('in the', np.float64(0.40563560896460615)),
#    ('on the screen', np.float64(0.38703609928098814)),
#    ('the screen', np.float64(0.38703609928098814)),
#    ('is the', np.float64(0.38087430668682853)),
#    ('notification when', np.float64(0.3725035244945295)),
#    ('which the', np.float64(0.35093573559617003)),
#    ('the buddy', np.float64(0.3434861243402316)),
#    ('which is', np.float64(0.3255332756530796)),
#    ('the nickname', np.float64(0.304217834032443))],
#   [('msn messenger', np.float64(-0.9851428511422907)),
#    ('is an', np.float64(-0.6232624858589005)),
#    ('requirements specification', np.float64(-0.5949360739500853)),
#    ('the xlet', np.float64(-0.5681920672137881)),
#    ('buddy list', np.float64(-0.5321539828620204)),
#    ('or other', np.float64(-0.45402444251912855)),
#    ('the msn messenger', np.float64(-0.37687188733374816)),
#    ('the msn', np.float64(-0.37687188733374816)),
#    ('to be', np.float64(-0.3491381037640179)),
#    ('an application', np.float64(-0.3331172222876903)),
#    ('is an application', np.float64(-0.3331172222876903)),
#    ('will be', np.float64(-0.29335388980441307)),
#    ('with the', np.float64(-0.2840526135336515)),
#    ('msn messenger xlet', np.float64(-0.21737577212341957)),
#    ('messenger xlet', np.float64(-0.21737577212341957)),
#    ('the status', np.float64(-0.19248526723318335)),
#    ('the user can', np.float64(-0.1897148871554561)),
#    ('able to', np.float64(-0.17429767725967182)),
#    ('contact list', np.float64(-0.1661445863683916)),
#    ('user can', np.float64(-0.1540628745466603))]),
#  'clarus high.doc': ([('clarus system shall', np.float64(1.488084452422088)),
#    ('system shall', np.float64(1.4261684332451783)),
#    ('the clarus system shall', np.float64(1.3306351234495877)),
#    ('the clarus', np.float64(1.2530365534268897)),
#    ('the clarus program', np.float64(1.115582260741087)),
#    ('clarus program', np.float64(1.115582260741087)),
#    ('program shall', np.float64(0.8400002303785812)),
#    ('the clarus program shall', np.float64(0.8400002303785812)),
#    ('clarus program shall', np.float64(0.8400002303785812)),
#    ('new data sources', np.float64(0.7746566122500634)),
#    ('shall be', np.float64(0.7355504001046306)),
#    ('clarus system', np.float64(0.7256194543317438)),
#    ('data sources', np.float64(0.7169738028259113)),
#    ('the clarus system', np.float64(0.6977291707268415)),
#    ('new data', np.float64(0.6499123449154265)),
#    ('to provide', np.float64(0.41613046812480203)),
#    ('registered users', np.float64(0.3823766632997815)),
#    ('access to', np.float64(0.36730737524112106)),
#    ('access to data', np.float64(0.36191295910677657)),
#    ('shall be able', np.float64(0.35618231313266935))],
#   [('the data', np.float64(-0.46523760212757875)),
#    ('the system', np.float64(-0.4458436724453972)),
#    ('to the', np.float64(-0.360197001904273)),
#    ('surface transportation', np.float64(-0.34346345165458475)),
#    ('will be', np.float64(-0.34165742269229765)),
#    ('for the', np.float64(-0.31410104859746635)),
#    ('and the', np.float64(-0.3012481323601737)),
#    ('system will', np.float64(-0.2641455538707435)),
#    ('clarus system will', np.float64(-0.26285647427366676)),
#    ('the clarus system will', np.float64(-0.26285647427366676)),
#    ('of data', np.float64(-0.253867772758172)),
#    ('to the clarus', np.float64(-0.24751379498009787)),
#    ('from the', np.float64(-0.24686430811132695)),
#    ('high level', np.float64(-0.24660542964419835)),
#    ('to the clarus system', np.float64(-0.22965837426990254)),
#    ('providers and', np.float64(-0.2197462702728365)),
#    ('clarus initiative', np.float64(-0.2172335848362267)),
#    ('data in', np.float64(-0.2148238760837698)),
#    ('in the', np.float64(-0.21014548371415295)),
#    ('can be', np.float64(-0.2070021474148336))]),
#  'library.pdf': ([('system provides', np.float64(1.2051838304957965)),
#    ('ability to', np.float64(1.1010744750390613)),
#    ('system supports', np.float64(0.8181853579759697)),
#    ('can be', np.float64(0.6605469696156515)),
#    ('access to', np.float64(0.6366566407805435)),
#    ('documentation is', np.float64(0.6012386407808333)),
#    ('staff can', np.float64(0.5846033321479315)),
#    ('staff and', np.float64(0.4150593480379933)),
#    ('management tools', np.float64(0.38492132740672413)),
#    ('staff can view', np.float64(0.3660574766911421)),
#    ('can view', np.float64(0.3660574766911421)),
#    ('record types', np.float64(0.3593232506370232)),
#    ('centrally managed', np.float64(0.3557963237588793)),
#    ('tables and', np.float64(0.3550383690486143)),
#    ('and control', np.float64(0.34219971438759894)),
#    ('such as', np.float64(0.34146193952274256)),
#    ('loan rules', np.float64(0.34058729358592754)),
#    ('ip address', np.float64(0.33650476361636883)),
#    ('check out', np.float64(0.32465444683976086)),
#    ('to specific', np.float64(0.30896544787749874))],
#   [('system administration', np.float64(-1.1752304671895326)),
#    ('the library', np.float64(-0.7700796709192401)),
#    ('it is', np.float64(-0.7271579457246238)),
#    ('library system', np.float64(-0.7072622647525586)),
#    ('and privileges', np.float64(-0.7006974847612606)),
#    ('system functions', np.float64(-0.6288268079035518)),
#    ('staff who', np.float64(-0.6204781444402927)),
#    ('the system', np.float64(-0.6096739173971885)),
#    ('managers include', np.float64(-0.5842745676491465)),
#    ('requirements for', np.float64(-0.5507330146820071)),
#    ('software developer', np.float64(-0.5113696859651977)),
#    ('high level', np.float64(-0.4997715056011326)),
#    ('software development', np.float64(-0.493730948057467)),
#    ('will be', np.float64(-0.4903748205294526)),
#    ('library services', np.float64(-0.473206023831924)),
#    ('system administration module', np.float64(-0.47271569436674876)),
#    ('administration module', np.float64(-0.47271569436674876)),
#    ('the current', np.float64(-0.43026434582812517)),
#    ('county library', np.float64(-0.42935818904951134)),
#    ('king county', np.float64(-0.42935818904951134))]),
#  'peazip.pdf': ([('and use', np.float64(0.8226860746912448)),
#    ('installation and use', np.float64(0.8226860746912448)),
#    ('the only', np.float64(0.6814686012132147)),
#    ('installation and', np.float64(0.6699652576086416)),
#    ('this feature', np.float64(0.6204765092977017)),
#    ('operating system', np.float64(0.5663813564997151)),
#    ('case of', np.float64(0.531878406201368)),
#    ('in case of', np.float64(0.531878406201368)),
#    ('in case', np.float64(0.531878406201368)),
#    ('for peazip', np.float64(0.4955746133422736)),
#    ('computer system', np.float64(0.4642079667821048)),
#    ('of this feature', np.float64(0.44325340602365115)),
#    ('it can', np.float64(0.41554754159584395)),
#    ('regardless of', np.float64(0.41554754159584395)),
#    ('users with', np.float64(0.4060007750937439)),
#    ('the computer system', np.float64(0.4011067469253903)),
#    ('the computer', np.float64(0.4011067469253903)),
#    ('would be', np.float64(0.38229375694703177)),
#    ('any computer system', np.float64(0.38110522028640104)),
#    ('any computer', np.float64(0.38110522028640104))],
#   [('is the', np.float64(-0.3943756920717814)),
#    ('concerned peazip', np.float64(-0.36888700773687666)),
#    ('far as', np.float64(-0.33368667639936833)),
#    ('as far', np.float64(-0.33368667639936833)),
#    ('as far as', np.float64(-0.33368667639936833)),
#    ('files and', np.float64(-0.3113670694515631)),
#    ('of peazip', np.float64(-0.3053563197775902)),
#    ('software requirements', np.float64(-0.281942800573541)),
#    ('is concerned', np.float64(-0.27631267326563497)),
#    ('be used', np.float64(-0.27174832036864527)),
#    ('archiving and', np.float64(-0.263904986942237)),
#    ('and compression', np.float64(-0.251275295192217)),
#    ('of any', np.float64(-0.24649149927257458)),
#    ('this software', np.float64(-0.23891508504776401)),
#    ('kind of', np.float64(-0.23744816273127525)),
#    ('software requirements specification', np.float64(-0.21413612324996845)),
#    ('and archive', np.float64(-0.21412241518965486)),
#    ('to any', np.float64(-0.21123906666523806)),
#    ('archiving and compression', np.float64(-0.20940736942830376)),
#    ('application and', np.float64(-0.2093246340201862))]),
#  'gparted.pdf': ([('you can', np.float64(0.9818202996174612)),
#    ('update and', np.float64(0.7975737871926418)),
#    ('of the program', np.float64(0.7404508507064012)),
#    ('and the', np.float64(0.7072167572289607)),
#    ('that is', np.float64(0.6578544691457834)),
#    ('to edit', np.float64(0.5962523377865777)),
#    ('cd dvd', np.float64(0.5639952611874306)),
#    ('or at', np.float64(0.5625085742516901)),
#    ('of data', np.float64(0.5567146741506023)),
#    ('from the', np.float64(0.5529727474905201)),
#    ('click ok', np.float64(0.5162332202484159)),
#    ('are not', np.float64(0.514663859650437)),
#    ('in the', np.float64(0.5000390189327855)),
#    ('at least', np.float64(0.4935380167270388)),
#    ('image file', np.float64(0.456608644342722)),
#    ('loss of data', np.float64(0.43439150284846234)),
#    ('loss of', np.float64(0.43439150284846234)),
#    ('as it', np.float64(0.4312095811364569)),
#    ('to run', np.float64(0.42778609899195014)),
#    ('have to', np.float64(0.42374803966610497))],
#   [('file systems', np.float64(-0.7259115815097812)),
#    ('disk partitions', np.float64(-0.6780643520911138)),
#    ('file system', np.float64(-0.6355434421668334)),
#    ('this document', np.float64(-0.6210315912286117)),
#    ('with the', np.float64(-0.6048770795902818)),
#    ('your computer', np.float64(-0.5240530242684482)),
#    ('and use', np.float64(-0.5232520723268608)),
#    ('there is', np.float64(-0.5217211947902796)),
#    ('gnu linux', np.float64(-0.5177035374370641)),
#    ('them in', np.float64(-0.5065957070209132)),
#    ('to the', np.float64(-0.47327590572992156)),
#    ('will be', np.float64(-0.47202103547755186)),
#    ('in section', np.float64(-0.4586031248272202)),
#    ('linux operating system', np.float64(-0.4583283052387469)),
#    ('linux operating', np.float64(-0.4583283052387469)),
#    ('such as', np.float64(-0.45475871970749476)),
#    ('for creating', np.float64(-0.425664865650067)),
#    ('operating systems', np.float64(-0.4163480174811732)),
#    ('or delete', np.float64(-0.4063338579069576)),
#    ('the gparted', np.float64(-0.39289328668154905))]),
#  'mashboot.pdf': ([('the system', np.float64(1.8722135382319791)),
#    ('user account', np.float64(0.9431949490193592)),
#    ('should have', np.float64(0.8958408536803888)),
#    ('the following', np.float64(0.8897631939820404)),
#    ('member should', np.float64(0.851246440941583)),
#    ('can be', np.float64(0.7577977752306968)),
#    ('by contributors', np.float64(0.6837530063496948)),
#    ('mashbot campaigns', np.float64(0.5955969962678037)),
#    ('should be', np.float64(0.5868636505784817)),
#    ('performed by', np.float64(0.5467750598662351)),
#    ('to an', np.float64(0.5398215949317268)),
#    ('the system administrator', np.float64(0.509605824667172)),
#    ('system administrator', np.float64(0.509605824667172)),
#    ('pieces of', np.float64(0.5037292230656284)),
#    ('campaigns should', np.float64(0.4296314494083038)),
#    ('multiple users', np.float64(0.4296314494083038)),
#    ('account roles', np.float64(0.42061187423624546)),
#    ('should be able', np.float64(0.4202928310113464)),
#    ('should be able to', np.float64(0.4202928310113464)),
#    ('more than', np.float64(0.40425705423792474))],
#   [('these requirements', np.float64(-1.0464517425524293)),
#    ('to be', np.float64(-0.7784320236381332)),
#    ('customer service', np.float64(-0.7178373403717657)),
#    ('will be', np.float64(-0.7150986535215289)),
#    ('to the', np.float64(-0.710955171778192)),
#    ('the user', np.float64(-0.688338327749422)),
#    ('the mashbot', np.float64(-0.6745177644011267)),
#    ('to provide', np.float64(-0.6269735335602827)),
#    ('will also', np.float64(-0.586045120693347)),
#    ('is to', np.float64(-0.5362214010804145)),
#    ('with the', np.float64(-0.4999850692555166)),
#    ('social media', np.float64(-0.49510415445356326)),
#    ('authentication mashbot', np.float64(-0.4817263145016816)),
#    ('for various', np.float64(-0.4713691565699683)),
#    ('mashbot is', np.float64(-0.4489401084515051)),
#    ('web application', np.float64(-0.43528827984268054)),
#    ('platform will', np.float64(-0.42666157641973707)),
#    ('there is', np.float64(-0.4037339417859594)),
#    ('on social', np.float64(-0.38391179425845584)),
#    ('existing service', np.float64(-0.38237001284465844))]),
#  'split merge.pdf': ([('the application', np.float64(1.040661992152305)),
#    ('must be', np.float64(0.851829322268295)),
#    ('is not', np.float64(0.6829132587202398)),
#    ('the user', np.float64(0.6488836933572999)),
#    ('the project', np.float64(0.6413163001691456)),
#    ('check for', np.float64(0.6253095364835616)),
#    ('to use', np.float64(0.6162292386274941)),
#    ('the computer system', np.float64(0.5820909945186696)),
#    ('system on', np.float64(0.5820909945186696)),
#    ('the computer', np.float64(0.5820909945186696)),
#    ('to provide', np.float64(0.5713207447276047)),
#    ('in the', np.float64(0.5669945916973558)),
#    ('or less', np.float64(0.4947219669414162)),
#    ('with every', np.float64(0.48778057000575314)),
#    ('to be', np.float64(0.4787722227241702)),
#    ('help messages', np.float64(0.4741359229827918)),
#    ('in this', np.float64(0.46908542151457683)),
#    ('pdfsam is', np.float64(0.4640735668034579)),
#    ('computer system', np.float64(0.4405260031746458)),
#    ('at time', np.float64(0.42898101238772246))],
#   [('of the', np.float64(-0.6490878785753168)),
#    ('this document', np.float64(-0.551974844058974)),
#    ('this project', np.float64(-0.5498550044805429)),
#    ('to handle', np.float64(-0.5331583340470042)),
#    ('it is', np.float64(-0.5156468727718576)),
#    ('is the', np.float64(-0.44732066736646725)),
#    ('open source', np.float64(-0.4342902510477756)),
#    ('who can', np.float64(-0.4220173916667396)),
#    ('pdf document', np.float64(-0.3464225488336898)),
#    ('is platform', np.float64(-0.3303351596983271)),
#    ('is platform independent', np.float64(-0.3303351596983271)),
#    ('platform independent', np.float64(-0.3303351596983271)),
#    ('program to', np.float64(-0.3290594552531327)),
#    ('it provides', np.float64(-0.32815818377992145)),
#    ('the basic', np.float64(-0.32456560203984774)),
#    ('selected pdf', np.float64(-0.31079753545903427)),
#    ('of the project', np.float64(-0.30910017176050697)),
#    ('and it', np.float64(-0.29609044997835804)),
#    ('the pdfsam', np.float64(-0.28870697362518977)),
#    ('file format', np.float64(-0.2869177242139346))]),
#  'e-store.doc': ([('shall be', np.float64(1.2665532990110062)),
#    ('the system', np.float64(1.246183420085588)),
#    ('system shall', np.float64(1.2211995953039945)),
#    ('the system shall', np.float64(0.956105115397931)),
#    ('the product', np.float64(0.5888323946007564)),
#    ('there are', np.float64(0.5403440642294313)),
#    ('the client', np.float64(0.5118843288880554)),
#    ('display the', np.float64(0.41909101869683146)),
#    ('will be', np.float64(0.37748718758978494)),
#    ('and product', np.float64(0.350929921230304)),
#    ('must be', np.float64(0.3502404471710262)),
#    ('components of the', np.float64(0.34926664388709106)),
#    ('components of', np.float64(0.34926664388709106)),
#    ('shall provide', np.float64(0.3367746684186415)),
#    ('it shall', np.float64(0.33609428249355067)),
#    ('use the', np.float64(0.32097576512194015)),
#    ('software system', np.float64(0.3101864431557031)),
#    ('shall communicate', np.float64(0.29066593202714275)),
#    ('store system', np.float64(0.26318395127299954)),
#    ('the store system', np.float64(0.26318395127299954))],
#   [('and its', np.float64(-0.6090298061652698)),
#    ('functional requirements', np.float64(-0.6004698493990865)),
#    ('of the', np.float64(-0.5479921349417913)),
#    ('this document', np.float64(-0.5313569603492712)),
#    ('can be', np.float64(-0.5118370921721506)),
#    ('stakeholders and', np.float64(-0.43324625416245294)),
#    ('requirements of', np.float64(-0.4239272385835539)),
#    ('product features', np.float64(-0.42110120073917645)),
#    ('the following', np.float64(-0.40507571612598553)),
#    ('it also', np.float64(-0.3928400515593844)),
#    ('the detail product', np.float64(-0.3796023332537452)),
#    ('the detail', np.float64(-0.3796023332537452)),
#    ('detail product', np.float64(-0.3796023332537452)),
#    ('description of', np.float64(-0.3735282837260048)),
#    ('gives the', np.float64(-0.36694140889271065)),
#    ('assist in', np.float64(-0.35832773787876915)),
#    ('to assist in', np.float64(-0.35832773787876915)),
#    ('to assist', np.float64(-0.35832773787876915)),
#    ('be used', np.float64(-0.3438855318534581)),
#    ('the stakeholders', np.float64(-0.3377976353177718))]),
#  'viper.doc': ([('the system', np.float64(1.5414390790135366)),
#    ('page contain', np.float64(1.0799450666040196)),
#    ('user can', np.float64(0.9444193512020229)),
#    ('customer supplier', np.float64(0.8360802871583002)),
#    ('will use', np.float64(0.6862537781931474)),
#    ('system will', np.float64(0.6658710065994764)),
#    ('the user', np.float64(0.6320287586266595)),
#    ('list box', np.float64(0.6069777446845752)),
#    ('through pages', np.float64(0.596070417704148)),
#    ('does not', np.float64(0.5595535189327221)),
#    ('his her', np.float64(0.5281867647574381)),
#    ('coordinator costumer', np.float64(0.4793278117205519)),
#    ('interact with', np.float64(0.4771599998370804)),
#    ('can be', np.float64(0.46603592294654234)),
#    ('this page', np.float64(0.44731532760913933)),
#    ('our system will', np.float64(0.4334883487515461)),
#    ('to the', np.float64(0.4297288000774881)),
#    ('click on', np.float64(0.4278925209626627)),
#    ('system will use', np.float64(0.42685378800930124)),
#    ('our system', np.float64(0.38512993914495613))],
#   [('the srs', np.float64(-0.5700383531202081)),
#    ('and the', np.float64(-0.5352670073603347)),
#    ('management process', np.float64(-0.48667706897813856)),
#    ('the system has', np.float64(-0.44174170414249103)),
#    ('system has', np.float64(-0.44174170414249103)),
#    ('and suppliers', np.float64(-0.4411918554720892)),
#    ('we must', np.float64(-0.4054018320676337)),
#    ('that we', np.float64(-0.3883629494751321)),
#    ('our scm', np.float64(-0.375009025325351)),
#    ('maintain customer', np.float64(-0.36935683888326304)),
#    ('organization and', np.float64(-0.36344289700875504)),
#    ('into the', np.float64(-0.35514841488289495)),
#    ('supply chain', np.float64(-0.3381772252491442)),
#    ('which include', np.float64(-0.32139803996875627)),
#    ('the first', np.float64(-0.31591257419162694)),
#    ('srs document', np.float64(-0.3096155381877736)),
#    ('customer service', np.float64(-0.3075211199610344)),
#    ('the same', np.float64(-0.2853395979817726)),
#    ('and the system', np.float64(-0.27679000664692005)),
#    ('and the system will', np.float64(-0.27679000664692005))]),
#  'virtual ed.doc': ([('must be', np.float64(1.065332695652082)),
#    ('the user', np.float64(1.0292698742830266)),
#    ('the use', np.float64(0.9709304381881785)),
#    ('conferencing feature', np.float64(0.8413010242234088)),
#    ('should be', np.float64(0.8069454080239609)),
#    ('and adobe', np.float64(0.7355277892025023)),
#    ('the portal', np.float64(0.7028529854966508)),
#    ('web conferencing', np.float64(0.6696600172658322)),
#    ('the system', np.float64(0.6367071922677873)),
#    ('in the', np.float64(0.6133021563329595)),
#    ('the content', np.float64(0.5855819692056542)),
#    ('and federal', np.float64(0.5735502505903806)),
#    ('state and', np.float64(0.5735502505903806)),
#    ('state and federal', np.float64(0.5735502505903806)),
#    ('used for', np.float64(0.5439283849655239)),
#    ('on the', np.float64(0.543516775599508)),
#    ('the conferencing feature', np.float64(0.5233696053545438)),
#    ('the conferencing', np.float64(0.5233696053545438)),
#    ('the local', np.float64(0.519531906254275)),
#    ('users to', np.float64(0.5043446190243016))],
#   [('virtual edu', np.float64(-0.6988300488866042)),
#    ('will have', np.float64(-0.4211927715111571)),
#    ('the same', np.float64(-0.40018774149997755)),
#    ('users will', np.float64(-0.38170237089676445)),
#    ('this document', np.float64(-0.37676480295830067)),
#    ('will also', np.float64(-0.3502347153220131)),
#    ('on demand', np.float64(-0.3473936244653665)),
#    ('entire system', np.float64(-0.3353658818848215)),
#    ('file sharing', np.float64(-0.31558164184185333)),
#    ('access to', np.float64(-0.3121001996705951)),
#    ('need to be', np.float64(-0.30501930928977405)),
#    ('need to', np.float64(-0.30501930928977405)),
#    ('need for', np.float64(-0.30433208632331)),
#    ('functional requirements', np.float64(-0.300321609855384)),
#    ('the university', np.float64(-0.29517025243390427)),
#    ('000 000', np.float64(-0.2928970242506436)),
#    ('requirements will be', np.float64(-0.29250488240198214)),
#    ('requirements will', np.float64(-0.29250488240198214)),
#    ('user profiles', np.float64(-0.2896329112738302)),
#    ('requirements that', np.float64(-0.2840540695841965))]),
#  '2009 - library.doc': ([('ability to', np.float64(1.1225787745391527)),
#    ('system provides', np.float64(1.1093735515875376)),
#    ('the system', np.float64(1.0911810988411152)),
#    ('can be', np.float64(0.7340058886232357)),
#    ('should be', np.float64(0.6879397332670937)),
#    ('in the', np.float64(0.6335505680683845)),
#    ('check outs', np.float64(0.5923629434146807)),
#    ('reports and', np.float64(0.5438235390097017)),
#    ('example staff', np.float64(0.5320898872818581)),
#    ('transactions are', np.float64(0.5281362024853948)),
#    ('by type', np.float64(0.5145898843213949)),
#    ('for example', np.float64(0.5105850922606057)),
#    ('based on', np.float64(0.4468199645936949)),
#    ('the results', np.float64(0.44035103046237717)),
#    ('the system provides', np.float64(0.4213476748107095)),
#    ('item records', np.float64(0.41218868737514686)),
#    ('grouped by', np.float64(0.403838262957709)),
#    ('can create', np.float64(0.403257552862287)),
#    ('per library', np.float64(0.4018413822316488)),
#    ('line staff', np.float64(0.39687456412166056))],
#   [('management processes', np.float64(-1.2432635985621472)),
#    ('it is', np.float64(-0.5238291659520256)),
#    ('of the', np.float64(-0.5025927059434875)),
#    ('for all', np.float64(-0.47259607308182605)),
#    ('the library', np.float64(-0.44502991869563535)),
#    ('pines library', np.float64(-0.43334447919781477)),
#    ('software development', np.float64(-0.42783855781291386)),
#    ('list of', np.float64(-0.42471837343348534)),
#    ('system functions', np.float64(-0.42454167341481774)),
#    ('the current', np.float64(-0.40902557995175093)),
#    ('needed for', np.float64(-0.3982416288687823)),
#    ('reports working', np.float64(-0.3895071397476839)),
#    ('reports working group', np.float64(-0.3895071397476839)),
#    ('working group', np.float64(-0.3895071397476839)),
#    ('staff who', np.float64(-0.3889489507089067)),
#    ('library card', np.float64(-0.383535622438514)),
#    ('analyzing the', np.float64(-0.37108637443330733)),
#    ('pines reports', np.float64(-0.3628106421798508)),
#    ('system administrators', np.float64(-0.36154627962377583)),
#    ('management processes shall', np.float64(-0.36071758285885364))])}

# %%
global_req_scores = defaultdict(float)
global_req_counts = defaultdict(int)

global_non_scores = defaultdict(float)
global_non_counts = defaultdict(int)

for src, (req_values, nonreq_values) in ling_words.items():
    # req_values is a list of (phrase, weight)
    for phrase, w in req_values:
        global_req_scores[phrase] += w
        global_req_counts[phrase] += 1

    for phrase, w in nonreq_values:
        global_non_scores[phrase] += w
        global_non_counts[phrase] += 1

# %%
# Convert to sorted lists
req_phrases = sorted(
    global_req_scores.items(),
    key=lambda x: x[1],
    reverse=True
)

nonreq_phrases = sorted(
    global_non_scores.items(),
    key=lambda x: x[1]
)

# %%
req_common = []
for p, s in req_phrases:
    if global_req_counts[p] >= 2:
        req_common.append((p, s, global_req_counts[p]))


nonreq_common = []
for p, s in nonreq_phrases:
    if global_non_counts[p] >= 2:
        nonreq_common.append((p, s, global_non_counts[p]))

# %%
print("Global requirement indicators:")
for phrase, score, count in req_common[:30]:
    print(f"{phrase:30s} total_score={score:.3f} sources={count}")

print("\nGlobal non requirement indicators:")
for phrase, score, count in nonreq_common[:30]:
    print(f"{phrase:30s} total_score={score:.3f} sources={count}")
# Out:
# Global requirement indicators:
# the system                     total_score=9.526 sources=8
# shall be                       total_score=8.911 sources=7
# should be                      total_score=5.385 sources=7
# system shall                   total_score=4.489 sources=4
# the user                       total_score=4.446 sources=6
# in the                         total_score=3.648 sources=7
# will be                        total_score=3.435 sources=4
# must be                        total_score=2.890 sources=5
# can be                         total_score=2.618 sources=4
# the application                total_score=2.534 sources=3
# system provides                total_score=2.315 sources=2
# ability to                     total_score=2.224 sources=2
# the system shall               total_score=2.135 sources=2
# at least                       total_score=2.097 sources=3
# the following                  total_score=1.546 sources=2
# to the                         total_score=1.309 sources=3
# and the                        total_score=1.233 sources=2
# this feature                   total_score=1.194 sources=2
# be able to                     total_score=1.133 sources=2
# be able                        total_score=1.133 sources=2
# will not                       total_score=1.070 sources=2
# may be                         total_score=1.059 sources=2
# access to                      total_score=1.004 sources=2
# to provide                     total_score=0.987 sources=2
# the computer system            total_score=0.983 sources=2
# the computer                   total_score=0.983 sources=2
# able to                        total_score=0.980 sources=2
# are not                        total_score=0.943 sources=2
# computer system                total_score=0.905 sources=2
# shall provide                  total_score=0.901 sources=2
#
# Global non requirement indicators:
# of the                         total_score=-3.942 sources=6
# this document                  total_score=-3.380 sources=7
# will be                        total_score=-3.144 sources=7
# to the                         total_score=-2.494 sources=5
# it is                          total_score=-2.238 sources=4
# with the                       total_score=-1.861 sources=4
# the same                       total_score=-1.603 sources=4
# functional requirements        total_score=-1.440 sources=4
# the system                     total_score=-1.433 sources=3
# is the                         total_score=-1.405 sources=3
# there is                       total_score=-1.370 sources=3
# the library                    total_score=-1.215 sources=2
# and the                        total_score=-1.185 sources=3
# there are                      total_score=-1.165 sources=2
# to be                          total_score=-1.128 sources=2
# the requirements               total_score=-1.114 sources=3
# system functions               total_score=-1.053 sources=2
# the following                  total_score=-1.047 sources=2
# the project                    total_score=-1.046 sources=2
# customer service               total_score=-1.025 sources=2
# staff who                      total_score=-1.009 sources=2
# is an                          total_score=-0.991 sources=2
# the srs                        total_score=-0.977 sources=2
# will also                      total_score=-0.936 sources=2
# is to                          total_score=-0.931 sources=2
# for the                        total_score=-0.929 sources=3
# software development           total_score=-0.922 sources=2
# the current                    total_score=-0.839 sources=2
# by the                         total_score=-0.804 sources=2
# in this                        total_score=-0.772 sources=2

# %%
df_req = pd.DataFrame(req_common[:30], columns=["Phrase", "Total Score", "Sources"])
df_req["Type"] = "Requirement"

df_non = pd.DataFrame(nonreq_common[:30], columns=["Phrase", "Total Score", "Sources"])
df_non["Type"] = "Non-requirement"

df_results = pd.concat([df_req, df_non], ignore_index=True)

# %%
df_results.to_csv("linguistic_indicators.csv", index=False)
